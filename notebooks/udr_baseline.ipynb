# %%
import sys
import os
sys.path.append(os.path.abspath('../')) # Point to project root

# %%
import importlib
import modules.trainer
import modules.utils
import modules.callbacks
import modules.env
import env.custom_hopper

# Force reload of the modules you changed
importlib.reload(modules.env)
importlib.reload(modules.callbacks)
importlib.reload(modules.utils)
importlib.reload(modules.trainer)
importlib.reload(env.custom_hopper)

# Re-import the specific functions into the global namespace
from modules.trainer import train_agent
from modules.utils import *
from env.custom_hopper import *

print("Modules reloaded successfully!")
# Out:
# Modules reloaded successfully!
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/gymnasium/envs/registration.py:644: UserWarning: WARN: Overriding environment CustomHopper-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/gymnasium/envs/registration.py:644: UserWarning: WARN: Overriding environment CustomHopper-source-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/gymnasium/envs/registration.py:644: UserWarning: WARN: Overriding environment CustomHopper-target-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/gymnasium/envs/registration.py:644: UserWarning: WARN: Overriding environment CustomHopper-shift-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
from modules.trainer import train_agent
from modules.utils import *
from env.custom_hopper import *

# %%
config = {
    'env_id': 'CustomHopper-source-v0',
    'algo': 'sac',
    'seed': 42,
    'timesteps': 1_000_000,
    'n_envs': 4,
    'vectorize': True,
    'normalize': True, 
    'lr': 1e-3,
    'gradient_steps': 2,
    'train_freq': 1,
    
    'mode': "udr"

}

# %%
# Training
train_agent(config, model_name="udr_baseline", log_dir="./logs/udr_experiment/")
# Out:
# Training with mode: udr
# --- STARTING NEW TRAINING ---
# Using cpu device
# Skipping DoraemonCallback for mode: udr
# Logging to ./tensorboard_logs/SAC_7
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.5     |
# |    ep_rew_mean     | 9.72     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 2631     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | -2.28    |
# |    critic_loss     | 6.36     |
# |    ent_coef        | 1        |
# |    ent_coef_loss   | -0.0025  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2        |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17.2     |
# |    ep_rew_mean     | 10.7     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 685      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | -4.79    |
# |    critic_loss     | 0.589    |
# |    ent_coef        | 0.964    |
# |    ent_coef_loss   | -0.184   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 38       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | 10.9     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 469      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 288      |
# | train/             |          |
# |    actor_loss      | -4.96    |
# |    critic_loss     | 0.342    |
# |    ent_coef        | 0.913    |
# |    ent_coef_loss   | -0.454   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 92       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | 13.7     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 393      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 388      |
# | train/             |          |
# |    actor_loss      | -5.19    |
# |    critic_loss     | 0.266    |
# |    ent_coef        | 0.869    |
# |    ent_coef_loss   | -0.707   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 142      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | 15.9     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 368      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 472      |
# | train/             |          |
# |    actor_loss      | -5.42    |
# |    critic_loss     | 0.438    |
# |    ent_coef        | 0.833    |
# |    ent_coef_loss   | -0.914   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 184      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | 16.5     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 348      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 616      |
# | train/             |          |
# |    actor_loss      | -6.01    |
# |    critic_loss     | 0.325    |
# |    ent_coef        | 0.775    |
# |    ent_coef_loss   | -1.26    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 256      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.5     |
# |    ep_rew_mean     | 16.9     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 337      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 720      |
# | train/             |          |
# |    actor_loss      | -6.18    |
# |    critic_loss     | 0.233    |
# |    ent_coef        | 0.736    |
# |    ent_coef_loss   | -1.53    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 308      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.9     |
# |    ep_rew_mean     | 20.8     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 334      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 808      |
# | train/             |          |
# |    actor_loss      | -6.6     |
# |    critic_loss     | 0.362    |
# |    ent_coef        | 0.705    |
# |    ent_coef_loss   | -1.74    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 352      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | 20.6     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 322      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 992      |
# | train/             |          |
# |    actor_loss      | -6.77    |
# |    critic_loss     | 0.267    |
# |    ent_coef        | 0.643    |
# |    ent_coef_loss   | -2.15    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 444      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.4     |
# |    ep_rew_mean     | 23.1     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 321      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1160     |
# | train/             |          |
# |    actor_loss      | -7.61    |
# |    critic_loss     | 0.237    |
# |    ent_coef        | 0.592    |
# |    ent_coef_loss   | -2.59    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 528      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.4     |
# |    ep_rew_mean     | 26.1     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 320      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1360     |
# | train/             |          |
# |    actor_loss      | -7.94    |
# |    critic_loss     | 0.21     |
# |    ent_coef        | 0.537    |
# |    ent_coef_loss   | -3.02    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 628      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.6     |
# |    ep_rew_mean     | 30.6     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 321      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1528     |
# | train/             |          |
# |    actor_loss      | -8.28    |
# |    critic_loss     | 0.193    |
# |    ent_coef        | 0.495    |
# |    ent_coef_loss   | -3.34    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 712      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 34       |
# |    ep_rew_mean     | 38.2     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 324      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1912     |
# | train/             |          |
# |    actor_loss      | -9.46    |
# |    critic_loss     | 0.202    |
# |    ent_coef        | 0.411    |
# |    ent_coef_loss   | -4.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 904      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 36.1     |
# |    ep_rew_mean     | 43.1     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 325      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2184     |
# | train/             |          |
# |    actor_loss      | -10.7    |
# |    critic_loss     | 0.266    |
# |    ent_coef        | 0.362    |
# |    ent_coef_loss   | -4.54    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1040     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 40.2     |
# |    ep_rew_mean     | 52       |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 327      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2572     |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 0.747    |
# |    ent_coef        | 0.304    |
# |    ent_coef_loss   | -5.05    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1234     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 43.9     |
# |    ep_rew_mean     | 62.2     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 329      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2964     |
# | train/             |          |
# |    actor_loss      | -13.8    |
# |    critic_loss     | 0.66     |
# |    ent_coef        | 0.255    |
# |    ent_coef_loss   | -5.26    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1430     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47       |
# |    ep_rew_mean     | 70.6     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 330      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3336     |
# | train/             |          |
# |    actor_loss      | -15.2    |
# |    critic_loss     | 0.616    |
# |    ent_coef        | 0.218    |
# |    ent_coef_loss   | -5.45    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1616     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.4     |
# |    ep_rew_mean     | 77.7     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 331      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 3708     |
# | train/             |          |
# |    actor_loss      | -17.5    |
# |    critic_loss     | 1.01     |
# |    ent_coef        | 0.188    |
# |    ent_coef_loss   | -5.66    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1802     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.4     |
# |    ep_rew_mean     | 83.7     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 331      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 4060     |
# | train/             |          |
# |    actor_loss      | -18.6    |
# |    critic_loss     | 1.3      |
# |    ent_coef        | 0.164    |
# |    ent_coef_loss   | -5.14    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1978     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.5     |
# |    ep_rew_mean     | 89.7     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 332      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 4400     |
# | train/             |          |
# |    actor_loss      | -20.3    |
# |    critic_loss     | 0.62     |
# |    ent_coef        | 0.144    |
# |    ent_coef_loss   | -5.64    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2148     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.5     |
# |    ep_rew_mean     | 93.3     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 333      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 4696     |
# | train/             |          |
# |    actor_loss      | -22.6    |
# |    critic_loss     | 1.6      |
# |    ent_coef        | 0.129    |
# |    ent_coef_loss   | -5.55    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2296     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.1     |
# |    ep_rew_mean     | 97.6     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 333      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 5012     |
# | train/             |          |
# |    actor_loss      | -24.2    |
# |    critic_loss     | 2.04     |
# |    ent_coef        | 0.115    |
# |    ent_coef_loss   | -5.41    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2454     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.3     |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 334      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 5348     |
# | train/             |          |
# |    actor_loss      | -25.4    |
# |    critic_loss     | 0.656    |
# |    ent_coef        | 0.103    |
# |    ent_coef_loss   | -4.71    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2622     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 58.2     |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 334      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 5624     |
# | train/             |          |
# |    actor_loss      | -26.3    |
# |    critic_loss     | 1.76     |
# |    ent_coef        | 0.0938   |
# |    ent_coef_loss   | -5.03    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2760     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59       |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 334      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 5964     |
# | train/             |          |
# |    actor_loss      | -28.2    |
# |    critic_loss     | 1.41     |
# |    ent_coef        | 0.084    |
# |    ent_coef_loss   | -4.05    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2930     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.5     |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 334      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 6284     |
# | train/             |          |
# |    actor_loss      | -29.2    |
# |    critic_loss     | 1.19     |
# |    ent_coef        | 0.0764   |
# |    ent_coef_loss   | -4.58    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3090     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.1     |
# |    ep_rew_mean     | 121      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 335      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 6620     |
# | train/             |          |
# |    actor_loss      | -32.4    |
# |    critic_loss     | 1.11     |
# |    ent_coef        | 0.0695   |
# |    ent_coef_loss   | -3.57    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3258     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.2     |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 335      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 6900     |
# | train/             |          |
# |    actor_loss      | -33.8    |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.0646   |
# |    ent_coef_loss   | -3.58    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3398     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 68.4     |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 335      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 7220     |
# | train/             |          |
# |    actor_loss      | -34.2    |
# |    critic_loss     | 0.99     |
# |    ent_coef        | 0.0595   |
# |    ent_coef_loss   | -3.67    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3558     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 70.7     |
# |    ep_rew_mean     | 139      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 335      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 7572     |
# | train/             |          |
# |    actor_loss      | -36.3    |
# |    critic_loss     | 1.93     |
# |    ent_coef        | 0.0544   |
# |    ent_coef_loss   | -4.13    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3734     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73       |
# |    ep_rew_mean     | 145      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 335      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 7912     |
# | train/             |          |
# |    actor_loss      | -38.4    |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.0502   |
# |    ent_coef_loss   | -3       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3904     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.1     |
# |    ep_rew_mean     | 151      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 335      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 8188     |
# | train/             |          |
# |    actor_loss      | -38.5    |
# |    critic_loss     | 0.94     |
# |    ent_coef        | 0.047    |
# |    ent_coef_loss   | -4.57    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4042     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77.2     |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 335      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 8552     |
# | train/             |          |
# |    actor_loss      | -39.7    |
# |    critic_loss     | 1        |
# |    ent_coef        | 0.0433   |
# |    ent_coef_loss   | -1.73    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4224     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 79.1     |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 335      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 8872     |
# | train/             |          |
# |    actor_loss      | -42.5    |
# |    critic_loss     | 1.35     |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | -3.39    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4384     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81       |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 336      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 9208     |
# | train/             |          |
# |    actor_loss      | -43.7    |
# |    critic_loss     | 1.72     |
# |    ent_coef        | 0.0384   |
# |    ent_coef_loss   | -2.44    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4552     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.3     |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 336      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 9568     |
# | train/             |          |
# |    actor_loss      | -44.6    |
# |    critic_loss     | 1.08     |
# |    ent_coef        | 0.037    |
# |    ent_coef_loss   | -0.893   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4732     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.4     |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 336      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 9924     |
# | train/             |          |
# |    actor_loss      | -47.5    |
# |    critic_loss     | 1.07     |
# |    ent_coef        | 0.0366   |
# |    ent_coef_loss   | -0.332   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4910     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.6     |
# |    ep_rew_mean     | 181      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 336      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 10256    |
# | train/             |          |
# |    actor_loss      | -48.6    |
# |    critic_loss     | 2.12     |
# |    ent_coef        | 0.0365   |
# |    ent_coef_loss   | 0.0817   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5076     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.6     |
# |    ep_rew_mean     | 185      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 336      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 10608    |
# | train/             |          |
# |    actor_loss      | -50.7    |
# |    critic_loss     | 1.42     |
# |    ent_coef        | 0.0368   |
# |    ent_coef_loss   | 1.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5252     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.1     |
# |    ep_rew_mean     | 185      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 336      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 10940    |
# | train/             |          |
# |    actor_loss      | -51.6    |
# |    critic_loss     | 1.81     |
# |    ent_coef        | 0.0375   |
# |    ent_coef_loss   | 0.458    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5418     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.4     |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 336      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 11256    |
# | train/             |          |
# |    actor_loss      | -51.7    |
# |    critic_loss     | 1.16     |
# |    ent_coef        | 0.0381   |
# |    ent_coef_loss   | 0.172    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5576     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.9     |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 336      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 11592    |
# | train/             |          |
# |    actor_loss      | -53.2    |
# |    critic_loss     | 1.73     |
# |    ent_coef        | 0.0382   |
# |    ent_coef_loss   | 0.332    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5744     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.8     |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 336      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 11936    |
# | train/             |          |
# |    actor_loss      | -54.4    |
# |    critic_loss     | 1.6      |
# |    ent_coef        | 0.0389   |
# |    ent_coef_loss   | 0.522    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5916     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.9     |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 337      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 12264    |
# | train/             |          |
# |    actor_loss      | -56.3    |
# |    critic_loss     | 1.6      |
# |    ent_coef        | 0.0391   |
# |    ent_coef_loss   | -0.167   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6080     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.6     |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 337      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 12624    |
# | train/             |          |
# |    actor_loss      | -56      |
# |    critic_loss     | 1.81     |
# |    ent_coef        | 0.0396   |
# |    ent_coef_loss   | 0.766    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6260     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.6     |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 336      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 12968    |
# | train/             |          |
# |    actor_loss      | -58.4    |
# |    critic_loss     | 1.67     |
# |    ent_coef        | 0.04     |
# |    ent_coef_loss   | 0.238    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6432     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.4     |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 336      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 13268    |
# | train/             |          |
# |    actor_loss      | -58.9    |
# |    critic_loss     | 1.46     |
# |    ent_coef        | 0.0403   |
# |    ent_coef_loss   | 0.899    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6582     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.6     |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 336      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 13628    |
# | train/             |          |
# |    actor_loss      | -59.7    |
# |    critic_loss     | 1.61     |
# |    ent_coef        | 0.041    |
# |    ent_coef_loss   | 1.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6762     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.8     |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 337      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 14012    |
# | train/             |          |
# |    actor_loss      | -60.6    |
# |    critic_loss     | 1.53     |
# |    ent_coef        | 0.0413   |
# |    ent_coef_loss   | 0.282    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6954     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.4     |
# |    ep_rew_mean     | 185      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 337      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 14380    |
# | train/             |          |
# |    actor_loss      | -61.7    |
# |    critic_loss     | 1.8      |
# |    ent_coef        | 0.0398   |
# |    ent_coef_loss   | 0.31     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7138     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.7     |
# |    ep_rew_mean     | 186      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 337      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 14680    |
# | train/             |          |
# |    actor_loss      | -63.8    |
# |    critic_loss     | 1.61     |
# |    ent_coef        | 0.0389   |
# |    ent_coef_loss   | -0.599   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7288     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 83.9     |
# |    ep_rew_mean     | 187      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 337      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 15044    |
# | train/             |          |
# |    actor_loss      | -64.5    |
# |    critic_loss     | 1.65     |
# |    ent_coef        | 0.0379   |
# |    ent_coef_loss   | -1.62    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7470     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.4     |
# |    ep_rew_mean     | 187      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 337      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 15420    |
# | train/             |          |
# |    actor_loss      | -66.2    |
# |    critic_loss     | 2.24     |
# |    ent_coef        | 0.0357   |
# |    ent_coef_loss   | 1.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7658     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.7     |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 337      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 15800    |
# | train/             |          |
# |    actor_loss      | -67.8    |
# |    critic_loss     | 1.94     |
# |    ent_coef        | 0.0362   |
# |    ent_coef_loss   | -0.623   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7848     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.2     |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 337      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 16144    |
# | train/             |          |
# |    actor_loss      | -67.1    |
# |    critic_loss     | 2.07     |
# |    ent_coef        | 0.0371   |
# |    ent_coef_loss   | 0.0861   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8020     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.8     |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 337      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 16508    |
# | train/             |          |
# |    actor_loss      | -68.6    |
# |    critic_loss     | 2.33     |
# |    ent_coef        | 0.0374   |
# |    ent_coef_loss   | -0.646   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8202     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86.4     |
# |    ep_rew_mean     | 192      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 337      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 16896    |
# | train/             |          |
# |    actor_loss      | -70      |
# |    critic_loss     | 1.88     |
# |    ent_coef        | 0.0389   |
# |    ent_coef_loss   | -0.329   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8396     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86.7     |
# |    ep_rew_mean     | 193      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 337      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 17256    |
# | train/             |          |
# |    actor_loss      | -68.7    |
# |    critic_loss     | 2.29     |
# |    ent_coef        | 0.0382   |
# |    ent_coef_loss   | -0.27    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8576     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.2     |
# |    ep_rew_mean     | 194      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 337      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 17628    |
# | train/             |          |
# |    actor_loss      | -72.7    |
# |    critic_loss     | 2.97     |
# |    ent_coef        | 0.0372   |
# |    ent_coef_loss   | 0.37     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8762     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.3     |
# |    ep_rew_mean     | 194      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 337      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 17976    |
# | train/             |          |
# |    actor_loss      | -73.7    |
# |    critic_loss     | 2.32     |
# |    ent_coef        | 0.0366   |
# |    ent_coef_loss   | 1.81     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8936     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.6     |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 337      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 18316    |
# | train/             |          |
# |    actor_loss      | -76      |
# |    critic_loss     | 2.37     |
# |    ent_coef        | 0.0371   |
# |    ent_coef_loss   | 0.176    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9106     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.9     |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 337      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 18704    |
# | train/             |          |
# |    actor_loss      | -74.7    |
# |    critic_loss     | 2.3      |
# |    ent_coef        | 0.0363   |
# |    ent_coef_loss   | 0.799    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9300     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.9     |
# |    ep_rew_mean     | 194      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 337      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 19016    |
# | train/             |          |
# |    actor_loss      | -76      |
# |    critic_loss     | 3.57     |
# |    ent_coef        | 0.0351   |
# |    ent_coef_loss   | -0.458   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9456     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.1     |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 337      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 19408    |
# | train/             |          |
# |    actor_loss      | -76.1    |
# |    critic_loss     | 2.03     |
# |    ent_coef        | 0.0364   |
# |    ent_coef_loss   | -0.145   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9652     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.2     |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 337      |
# |    time_elapsed    | 58       |
# |    total_timesteps | 19784    |
# | train/             |          |
# |    actor_loss      | -76.8    |
# |    critic_loss     | 2.19     |
# |    ent_coef        | 0.0371   |
# |    ent_coef_loss   | -0.385   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9840     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.7     |
# |    ep_rew_mean     | 196      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 337      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 20212    |
# | train/             |          |
# |    actor_loss      | -76.7    |
# |    critic_loss     | 2.09     |
# |    ent_coef        | 0.0384   |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10054    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.8     |
# |    ep_rew_mean     | 196      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 337      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 20496    |
# | train/             |          |
# |    actor_loss      | -78.8    |
# |    critic_loss     | 2.41     |
# |    ent_coef        | 0.0381   |
# |    ent_coef_loss   | -0.647   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10196    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.7     |
# |    ep_rew_mean     | 196      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 337      |
# |    time_elapsed    | 61       |
# |    total_timesteps | 20840    |
# | train/             |          |
# |    actor_loss      | -78.9    |
# |    critic_loss     | 2.45     |
# |    ent_coef        | 0.0398   |
# |    ent_coef_loss   | 1.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10368    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.6     |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 337      |
# |    time_elapsed    | 62       |
# |    total_timesteps | 21168    |
# | train/             |          |
# |    actor_loss      | -80.4    |
# |    critic_loss     | 2.23     |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10532    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.5     |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 337      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 21492    |
# | train/             |          |
# |    actor_loss      | -79.3    |
# |    critic_loss     | 2.6      |
# |    ent_coef        | 0.0409   |
# |    ent_coef_loss   | 0.348    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10694    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.6     |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 337      |
# |    time_elapsed    | 64       |
# |    total_timesteps | 21848    |
# | train/             |          |
# |    actor_loss      | -83.4    |
# |    critic_loss     | 2.31     |
# |    ent_coef        | 0.0397   |
# |    ent_coef_loss   | -0.412   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10872    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89       |
# |    ep_rew_mean     | 196      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 337      |
# |    time_elapsed    | 65       |
# |    total_timesteps | 22236    |
# | train/             |          |
# |    actor_loss      | -81.4    |
# |    critic_loss     | 1.87     |
# |    ent_coef        | 0.0388   |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11066    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89       |
# |    ep_rew_mean     | 196      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 337      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 22564    |
# | train/             |          |
# |    actor_loss      | -82.1    |
# |    critic_loss     | 4.53     |
# |    ent_coef        | 0.0366   |
# |    ent_coef_loss   | 0.177    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11230    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.4     |
# |    ep_rew_mean     | 197      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 337      |
# |    time_elapsed    | 68       |
# |    total_timesteps | 22972    |
# | train/             |          |
# |    actor_loss      | -85.2    |
# |    critic_loss     | 2.41     |
# |    ent_coef        | 0.0389   |
# |    ent_coef_loss   | 1.42     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11434    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.7     |
# |    ep_rew_mean     | 197      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 337      |
# |    time_elapsed    | 69       |
# |    total_timesteps | 23408    |
# | train/             |          |
# |    actor_loss      | -84.6    |
# |    critic_loss     | 2.57     |
# |    ent_coef        | 0.0426   |
# |    ent_coef_loss   | -0.309   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11652    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.4     |
# |    ep_rew_mean     | 196      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 337      |
# |    time_elapsed    | 70       |
# |    total_timesteps | 23756    |
# | train/             |          |
# |    actor_loss      | -83.4    |
# |    critic_loss     | 2.86     |
# |    ent_coef        | 0.0447   |
# |    ent_coef_loss   | -0.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11826    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.8     |
# |    ep_rew_mean     | 197      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 337      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 24128    |
# | train/             |          |
# |    actor_loss      | -84.7    |
# |    critic_loss     | 9.73     |
# |    ent_coef        | 0.0455   |
# |    ent_coef_loss   | 0.114    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12012    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.4     |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 337      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 24572    |
# | train/             |          |
# |    actor_loss      | -86      |
# |    critic_loss     | 2.43     |
# |    ent_coef        | 0.0446   |
# |    ent_coef_loss   | -0.84    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12234    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.8     |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 337      |
# |    time_elapsed    | 74       |
# |    total_timesteps | 25120    |
# | train/             |          |
# |    actor_loss      | -85.6    |
# |    critic_loss     | 2.55     |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | 0.146    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12508    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.6     |
# |    ep_rew_mean     | 201      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 337      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 25520    |
# | train/             |          |
# |    actor_loss      | -88.8    |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.0476   |
# |    ent_coef_loss   | -1.54    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12708    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.2     |
# |    ep_rew_mean     | 202      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 337      |
# |    time_elapsed    | 76       |
# |    total_timesteps | 25944    |
# | train/             |          |
# |    actor_loss      | -89.2    |
# |    critic_loss     | 1.98     |
# |    ent_coef        | 0.0467   |
# |    ent_coef_loss   | -0.42    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12920    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 93.9     |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 337      |
# |    time_elapsed    | 78       |
# |    total_timesteps | 26416    |
# | train/             |          |
# |    actor_loss      | -88.5    |
# |    critic_loss     | 2.77     |
# |    ent_coef        | 0.0448   |
# |    ent_coef_loss   | -1.51    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13156    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.6     |
# |    ep_rew_mean     | 205      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 337      |
# |    time_elapsed    | 79       |
# |    total_timesteps | 26828    |
# | train/             |          |
# |    actor_loss      | -89      |
# |    critic_loss     | 3.74     |
# |    ent_coef        | 0.045    |
# ...
# | train/             |          |
# |    actor_loss      | -207     |
# |    critic_loss     | 10.4     |
# |    ent_coef        | 0.0427   |
# |    ent_coef_loss   | -0.481   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 485656   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 267      |
# |    ep_rew_mean     | 819      |
# | time/              |          |
# |    episodes        | 4040     |
# |    fps             | 347      |
# |    time_elapsed    | 2802     |
# |    total_timesteps | 972800   |
# | train/             |          |
# |    actor_loss      | -203     |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 0.0439   |
# |    ent_coef_loss   | 0.144    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 486348   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 268      |
# |    ep_rew_mean     | 821      |
# | time/              |          |
# |    episodes        | 4044     |
# |    fps             | 347      |
# |    time_elapsed    | 2804     |
# |    total_timesteps | 973476   |
# | train/             |          |
# |    actor_loss      | -196     |
# |    critic_loss     | 8.86     |
# |    ent_coef        | 0.0452   |
# |    ent_coef_loss   | -0.44    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 486686   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 264      |
# |    ep_rew_mean     | 806      |
# | time/              |          |
# |    episodes        | 4048     |
# |    fps             | 347      |
# |    time_elapsed    | 2808     |
# |    total_timesteps | 974668   |
# | train/             |          |
# |    actor_loss      | -207     |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0446   |
# |    ent_coef_loss   | -0.234   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 487282   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 268      |
# |    ep_rew_mean     | 823      |
# | time/              |          |
# |    episodes        | 4052     |
# |    fps             | 347      |
# |    time_elapsed    | 2811     |
# |    total_timesteps | 975856   |
# | train/             |          |
# |    actor_loss      | -200     |
# |    critic_loss     | 12.2     |
# |    ent_coef        | 0.0432   |
# |    ent_coef_loss   | 0.397    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 487876   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 266      |
# |    ep_rew_mean     | 819      |
# | time/              |          |
# |    episodes        | 4056     |
# |    fps             | 347      |
# |    time_elapsed    | 2813     |
# |    total_timesteps | 976440   |
# | train/             |          |
# |    actor_loss      | -201     |
# |    critic_loss     | 12.5     |
# |    ent_coef        | 0.0426   |
# |    ent_coef_loss   | -1.08    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 488168   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 263      |
# |    ep_rew_mean     | 805      |
# | time/              |          |
# |    episodes        | 4060     |
# |    fps             | 347      |
# |    time_elapsed    | 2818     |
# |    total_timesteps | 977972   |
# | train/             |          |
# |    actor_loss      | -199     |
# |    critic_loss     | 16.1     |
# |    ent_coef        | 0.0463   |
# |    ent_coef_loss   | 0.577    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 488934   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 269      |
# |    ep_rew_mean     | 820      |
# | time/              |          |
# |    episodes        | 4064     |
# |    fps             | 346      |
# |    time_elapsed    | 2822     |
# |    total_timesteps | 979212   |
# | train/             |          |
# |    actor_loss      | -198     |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.0434   |
# |    ent_coef_loss   | -0.998   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 489554   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 268      |
# |    ep_rew_mean     | 816      |
# | time/              |          |
# |    episodes        | 4068     |
# |    fps             | 346      |
# |    time_elapsed    | 2824     |
# |    total_timesteps | 980152   |
# | train/             |          |
# |    actor_loss      | -201     |
# |    critic_loss     | 11.5     |
# |    ent_coef        | 0.044    |
# |    ent_coef_loss   | -0.831   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 490024   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 271      |
# |    ep_rew_mean     | 826      |
# | time/              |          |
# |    episodes        | 4072     |
# |    fps             | 346      |
# |    time_elapsed    | 2829     |
# |    total_timesteps | 981632   |
# | train/             |          |
# |    actor_loss      | -206     |
# |    critic_loss     | 10.9     |
# |    ent_coef        | 0.0459   |
# |    ent_coef_loss   | 0.353    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 490764   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 272      |
# |    ep_rew_mean     | 828      |
# | time/              |          |
# |    episodes        | 4076     |
# |    fps             | 346      |
# |    time_elapsed    | 2831     |
# |    total_timesteps | 982504   |
# | train/             |          |
# |    actor_loss      | -205     |
# |    critic_loss     | 8.27     |
# |    ent_coef        | 0.0443   |
# |    ent_coef_loss   | 0.528    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 491200   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 279      |
# |    ep_rew_mean     | 852      |
# | time/              |          |
# |    episodes        | 4080     |
# |    fps             | 346      |
# |    time_elapsed    | 2836     |
# |    total_timesteps | 984088   |
# | train/             |          |
# |    actor_loss      | -204     |
# |    critic_loss     | 16.6     |
# |    ent_coef        | 0.0433   |
# |    ent_coef_loss   | -0.338   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 491992   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 278      |
# |    ep_rew_mean     | 847      |
# | time/              |          |
# |    episodes        | 4084     |
# |    fps             | 346      |
# |    time_elapsed    | 2839     |
# |    total_timesteps | 985184   |
# | train/             |          |
# |    actor_loss      | -204     |
# |    critic_loss     | 8.59     |
# |    ent_coef        | 0.0448   |
# |    ent_coef_loss   | 0.128    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 492540   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 277      |
# |    ep_rew_mean     | 844      |
# | time/              |          |
# |    episodes        | 4088     |
# |    fps             | 346      |
# |    time_elapsed    | 2842     |
# |    total_timesteps | 986124   |
# | train/             |          |
# |    actor_loss      | -201     |
# |    critic_loss     | 9.33     |
# |    ent_coef        | 0.045    |
# |    ent_coef_loss   | -1.09    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 493010   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 274      |
# |    ep_rew_mean     | 834      |
# | time/              |          |
# |    episodes        | 4092     |
# |    fps             | 346      |
# |    time_elapsed    | 2844     |
# |    total_timesteps | 986908   |
# | train/             |          |
# |    actor_loss      | -203     |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.0426   |
# |    ent_coef_loss   | 0.0862   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 493402   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 275      |
# |    ep_rew_mean     | 835      |
# | time/              |          |
# |    episodes        | 4096     |
# |    fps             | 346      |
# |    time_elapsed    | 2847     |
# |    total_timesteps | 987756   |
# | train/             |          |
# |    actor_loss      | -202     |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.0442   |
# |    ent_coef_loss   | -0.741   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 493826   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 269      |
# |    ep_rew_mean     | 813      |
# | time/              |          |
# |    episodes        | 4100     |
# |    fps             | 346      |
# |    time_elapsed    | 2849     |
# |    total_timesteps | 988356   |
# | train/             |          |
# |    actor_loss      | -199     |
# |    critic_loss     | 8        |
# |    ent_coef        | 0.0458   |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 494126   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 264      |
# |    ep_rew_mean     | 788      |
# | time/              |          |
# |    episodes        | 4104     |
# |    fps             | 346      |
# |    time_elapsed    | 2853     |
# |    total_timesteps | 989856   |
# | train/             |          |
# |    actor_loss      | -205     |
# |    critic_loss     | 8.41     |
# |    ent_coef        | 0.0405   |
# |    ent_coef_loss   | 0.553    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 494876   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 263      |
# |    ep_rew_mean     | 785      |
# | time/              |          |
# |    episodes        | 4108     |
# |    fps             | 346      |
# |    time_elapsed    | 2855     |
# |    total_timesteps | 990588   |
# | train/             |          |
# |    actor_loss      | -203     |
# |    critic_loss     | 12.1     |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | -0.243   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495242   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 264      |
# |    ep_rew_mean     | 787      |
# | time/              |          |
# |    episodes        | 4112     |
# |    fps             | 346      |
# |    time_elapsed    | 2859     |
# |    total_timesteps | 991924   |
# | train/             |          |
# |    actor_loss      | -203     |
# |    critic_loss     | 10.2     |
# |    ent_coef        | 0.0421   |
# |    ent_coef_loss   | -0.0747  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495910   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 266      |
# |    ep_rew_mean     | 794      |
# | time/              |          |
# |    episodes        | 4116     |
# |    fps             | 346      |
# |    time_elapsed    | 2864     |
# |    total_timesteps | 993320   |
# | train/             |          |
# |    actor_loss      | -204     |
# |    critic_loss     | 13.5     |
# |    ent_coef        | 0.0449   |
# |    ent_coef_loss   | 0.267    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 496608   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 271      |
# |    ep_rew_mean     | 807      |
# | time/              |          |
# |    episodes        | 4120     |
# |    fps             | 346      |
# |    time_elapsed    | 2867     |
# |    total_timesteps | 994348   |
# | train/             |          |
# |    actor_loss      | -204     |
# |    critic_loss     | 8.18     |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | 0.0667   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 497122   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 272      |
# |    ep_rew_mean     | 816      |
# | time/              |          |
# |    episodes        | 4124     |
# |    fps             | 346      |
# |    time_elapsed    | 2871     |
# |    total_timesteps | 995760   |
# | train/             |          |
# |    actor_loss      | -198     |
# |    critic_loss     | 10.3     |
# |    ent_coef        | 0.0433   |
# |    ent_coef_loss   | -0.788   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 497828   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 273      |
# |    ep_rew_mean     | 821      |
# | time/              |          |
# |    episodes        | 4128     |
# |    fps             | 346      |
# |    time_elapsed    | 2875     |
# |    total_timesteps | 997128   |
# | train/             |          |
# |    actor_loss      | -203     |
# |    critic_loss     | 12       |
# |    ent_coef        | 0.0427   |
# |    ent_coef_loss   | -0.469   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498512   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 270      |
# |    ep_rew_mean     | 813      |
# | time/              |          |
# |    episodes        | 4132     |
# |    fps             | 346      |
# |    time_elapsed    | 2877     |
# |    total_timesteps | 997764   |
# | train/             |          |
# |    actor_loss      | -207     |
# |    critic_loss     | 9.22     |
# |    ent_coef        | 0.0404   |
# |    ent_coef_loss   | -0.26    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498830   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 272      |
# |    ep_rew_mean     | 821      |
# | time/              |          |
# |    episodes        | 4136     |
# |    fps             | 346      |
# |    time_elapsed    | 2882     |
# |    total_timesteps | 999476   |
# | train/             |          |
# |    actor_loss      | -200     |
# |    critic_loss     | 122      |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | 0.405    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499686   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 276      |
# |    ep_rew_mean     | 837      |
# | time/              |          |
# |    episodes        | 4140     |
# |    fps             | 346      |
# |    time_elapsed    | 2883     |
# |    total_timesteps | 999972   |
# | train/             |          |
# |    actor_loss      | -203     |
# |    critic_loss     | 14.7     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | 0.388    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499934   |
# ---------------------------------
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Training
# ----> 2 train_agent(config, model_name="udr_baseline", log_dir="./logs/udr_experiment/")
#
# File ~/Desktop/Università/Robot_Learning/project/project-extension-bartolini_benvenuti/modules/trainer.py:172, in train_agent(config, log_dir, model_name, resume_step)
#     169     print("Interrupted! Saving emergency checkpoint...")
#     170     doraemon_cb.save_checkpoint()
# --> 172 return model, env, doraemon_cb
#
# UnboundLocalError: local variable 'doraemon_cb' referenced before assignment

# %%
# ONLY USE IF TRAINING WAS INTERRUPTED AND YOU HAVE CHECKPOINTS

import os
import re

# CHECKPOINT VERIFICATION

checkpoint_dir = "./logs/checkpoints"
if os.path.exists(checkpoint_dir):
    print("Files found:", os.listdir(checkpoint_dir))
else:
    print("No checkpoints found! The interrupt save didn't work.")


# RESUME TRAINING FROM CHECKPOINT

# 1. Find the latest checkpoint step
log_dir = "./logs/"
ckpt_dir = os.path.join(log_dir, "checkpoints")

latest_step = None
if os.path.exists(ckpt_dir):
    # regex to find numbers in filenames
    steps = [int(re.search(r'\d+', f).group()) for f in os.listdir(ckpt_dir) if "model_" in f]
    if steps:
        latest_step = max(steps)

print(f"Resuming from step: {latest_step}")

# 2. Resume Training
if latest_step is not None:
    # Pass the step number to resume_step
    model, env, doraemon_cb = train_agent(config, log_dir=log_dir, resume_step=latest_step)
else:
    print("Could not find a checkpoint to resume.")

# %%
# Used to visualize training metrics through TensorBoard
! tensorboard --logdir ./tensorboard_logs/

# Note: if you want to run Tensorboard from terminal, simply use the command above
# Out:
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/tensorboard/default.py:30: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# TensorFlow installation not found - running with reduced feature set.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.20.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
import json
import numpy as np

class DoraemonMockCallback:
    def __init__(self, json_path):
        # Load the JSON data
        with open(json_path, 'r') as f:
            data = json.load(f)
        
        # Extract the history
        self.history = data.get("history", {}) 
        
        print(f"Data loaded. Updates found: {len(self.history.get('entropy', []))}")


doraemon_cb = DoraemonMockCallback('logs/doraemon_state_20000000.json')

plot_doraemon_dynamics(doraemon_cb)
# Out:
# Data loaded. Updates found: 541

# %%
from modules.utils import *
from stable_baselines3 import SAC

# Define the raw environments
source_env = gym.make('CustomHopper-source-v0')
target_env = gym.make('CustomHopper-target-v0')

# Reconstruct the model name used in training
model_name = f"{config['algo']}_doraemon_{config['seed']}"
model_name = "final"

print("Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...")
model = SAC.load("./logs/udr_experiment/udr_baseline", device="cpu")

# Run evaluation
evaluate_sim2real(model, source_env, target_env, log_dir="./logs/", model_name=model_name)
# Out:
# Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...
# Loaded Normalization stats from ./logs//final_vecnormalize.pkl
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# --- Evaluating on SOURCE Env (Simulation) ---
# Reward: 43.91 +/- 0.93
# Length: 25.70 +/- 0.56 steps
#
# --- Evaluating on TARGET Env (Real/Shifted) ---
# Reward: 46.95 +/- 1.24
# Length: 28.70 +/- 0.78 steps
# (np.float64(43.90747263431549), np.float64(46.9465738594532))

# %%
import matplotlib.pyplot as plt
import numpy as np
import gymnasium as gym
from gymnasium.envs.registration import register
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.evaluation import evaluate_policy

# --- 1. CARICAMENTO MODELLO ---
print("Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...")
model = SAC.load("./logs/udr_experiment/udr_baseline", device="cpu")

# --- 3. CONFIGURAZIONE ---
mass_shifts = [-2, -1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5, 2.0]
n_eval_episodes = 20
results_mean = []
results_std = []

print(f"\nAvvio valutazione robustezza su {len(mass_shifts)} configurazioni...")
print("-" * 60)

# --- 4. LOOP DI VALUTAZIONE ---
for shift in mass_shifts:
    env = gym.make("CustomHopper-shift-v0", mass_shift=shift)
    env = DummyVecEnv([lambda: env])
    
    norm_path = f"./logs/udr_experiment/udr_baseline_vecnormalize.pkl"
    try:
        env = VecNormalize.load(norm_path, env)
        env.training = False      
        env.norm_reward = False   
    except FileNotFoundError:
        pass 

    episode_rewards, episode_lengths = evaluate_policy(
        model, 
        env, 
        n_eval_episodes=n_eval_episodes, 
        deterministic=True, 
        return_episode_rewards=True
    )
    
    mean_r = np.mean(episode_rewards)
    std_r = np.std(episode_rewards)
    results_mean.append(mean_r)
    results_std.append(std_r)
    
    print(f"Shift {shift:+.1f} kg | Reward: {mean_r:8.2f} +/- {std_r:6.2f}")
    
    env.close()

# --- 5. PLOTTING (BARRE + CURVA) ---
results_mean = np.array(results_mean)
results_std = np.array(results_std)

if 0.0 in mass_shifts:
    baseline_idx = mass_shifts.index(0.0)
    baseline_reward = results_mean[baseline_idx]
else:
    baseline_reward = np.max(results_mean)

percentages = (results_mean / baseline_reward) * 100

# Creazione Grafici
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

bar_width = 0.4
x_pos = np.arange(len(mass_shifts))

# --- Grafico A: Performance Assoluta ---
# 1. Le Barre
bars1 = ax1.bar(x_pos, results_mean, yerr=results_std, align='center', 
               alpha=0.6, ecolor='black', capsize=5, width=bar_width, 
               color='royalblue', label='Average Reward (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax1.plot(x_pos, results_mean, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax1.axhline(y=baseline_reward, color='red', linestyle='--', linewidth=1.5, label='Baseline')
ax1.set_title('Absolute Performance vs. Torso Mass Shift')
ax1.set_xlabel('Torso Mass Shift (kg)')
ax1.set_ylabel('Mean Reward')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(mass_shifts)
ax1.grid(True, axis='y', alpha=0.3)
ax1.legend()

# Etichette barre
ax1.bar_label(bars1, fmt='%.0f', padding=3)


# --- Grafico B: Performance Relativa ---
# 1. Le Barre
bars2 = ax2.bar(x_pos, percentages, align='center', 
                alpha=0.6, width=bar_width, 
                color='purple', label='% of Baseline (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax2.plot(x_pos, percentages, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax2.axhline(y=100.0, color='black', linestyle='--', alpha=0.5, label='Baseline (100%)')
ax2.set_title('Robustness Profile (% of Baseline)')
ax2.set_xlabel('Torso Mass Shift (kg)')
ax2.set_ylabel('Performance (%)')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(mass_shifts)
ax2.set_ylim(0, max(115, np.max(percentages) + 10)) 
ax2.grid(True, axis='y', alpha=0.3)
ax2.legend()

# Etichette barre
ax2.bar_label(bars2, fmt='%.1f%%', padding=3)

plt.tight_layout()
plt.show()
# Out:
# Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...
# Environment 'CustomHopper-shift-v0' registrato correttamente.
#
# Avvio valutazione robustezza su 9 configurazioni...
# ------------------------------------------------------------
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/gymnasium/envs/registration.py:644: UserWarning: WARN: Overriding environment CustomHopper-shift-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# Shift -2.0 kg | Reward:  1414.02 +/-  58.83
# Shift -1.5 kg | Reward:  1498.84 +/-  30.93
# Shift -1.0 kg | Reward:  1583.79 +/-  23.89
# Shift -0.5 kg | Reward:  1643.79 +/-  19.46
# Shift +0.0 kg | Reward:  1683.12 +/-  49.53
# Shift +0.5 kg | Reward:  1682.31 +/-   6.78
# Shift +1.0 kg | Reward:  1624.73 +/-  33.03
# Shift +1.5 kg | Reward:  1358.96 +/-  29.21
# Shift +2.0 kg | Reward:  1461.52 +/- 210.72

# %%
import matplotlib.pyplot as plt
import numpy as np
import gymnasium as gym
from gymnasium.envs.registration import register
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.evaluation import evaluate_policy

# --- 1. CARICAMENTO MODELLO ---
print("Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...")
model = SAC.load("./logs/udr_experiment/udr_baseline", device="cpu")

# --- 3. CONFIGURAZIONE ---
floor_friction_shifts = [-0.9, -0.6, -0.3, 0.0, 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7]
n_eval_episodes = 20
results_mean = []
results_std = []

print(f"\nAvvio valutazione robustezza su {len(floor_friction_shifts)} configurazioni...")
print("-" * 60)

# --- 4. LOOP DI VALUTAZIONE ---
for shift in floor_friction_shifts:
    env = gym.make("CustomHopper-shift-v0", floor_friction_shift=shift, mass_shift=0.0)
    env = DummyVecEnv([lambda: env])
    
    norm_path = f"./logs/udr_experiment/udr_baseline_vecnormalize.pkl"
    try:
        env = VecNormalize.load(norm_path, env)
        env.training = False      
        env.norm_reward = False   
    except FileNotFoundError:
        pass 

    episode_rewards, episode_lengths = evaluate_policy(
        model, 
        env, 
        n_eval_episodes=n_eval_episodes, 
        deterministic=True, 
        return_episode_rewards=True
    )
    
    mean_r = np.mean(episode_rewards)
    std_r = np.std(episode_rewards)
    results_mean.append(mean_r)
    results_std.append(std_r)
    
    print(f"Shift {shift:+.2f} | Reward: {mean_r:8.2f} +/- {std_r:6.2f}")
    
    env.close()

# --- 5. PLOTTING (BARRE + CURVA) ---
results_mean = np.array(results_mean)
results_std = np.array(results_std)

if 0.0 in floor_friction_shifts:
    baseline_idx = floor_friction_shifts.index(0.0)
    baseline_reward = results_mean[baseline_idx]
else:
    baseline_reward = np.max(results_mean)

percentages = (results_mean / baseline_reward) * 100

# Creazione Grafici
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

bar_width = 0.4
x_pos = np.arange(len(floor_friction_shifts))

# --- Grafico A: Performance Assoluta ---
# 1. Le Barre
bars1 = ax1.bar(x_pos, results_mean, yerr=results_std, align='center', 
               alpha=0.6, ecolor='black', capsize=5, width=bar_width, 
               color='royalblue', label='Average Reward (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax1.plot(x_pos, results_mean, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax1.axhline(y=baseline_reward, color='red', linestyle='--', linewidth=1.5, label='Baseline')
ax1.set_title('Absolute Performance vs. Floor Friction Shift')
ax1.set_xlabel('Floor Friction Shift')
ax1.set_ylabel('Mean Reward')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(floor_friction_shifts)
ax1.grid(True, axis='y', alpha=0.3)
ax1.legend()

# Etichette barre
ax1.bar_label(bars1, fmt='%.0f', padding=3)


# --- Grafico B: Performance Relativa ---
# 1. Le Barre
bars2 = ax2.bar(x_pos, percentages, align='center', 
                alpha=0.6, width=bar_width, 
                color='purple', label='% of Baseline (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax2.plot(x_pos, percentages, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax2.axhline(y=100.0, color='black', linestyle='--', alpha=0.5, label='Baseline (100%)')
ax2.set_title('Robustness Profile (% of Baseline)')
ax2.set_xlabel('Floor Friction Shift')
ax2.set_ylabel('Performance (%)')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(floor_friction_shifts)
ax2.set_ylim(0, max(115, np.max(percentages) + 10)) 
ax2.grid(True, axis='y', alpha=0.3)
ax2.legend()

# Etichette barre
ax2.bar_label(bars2, fmt='%.1f%%', padding=3)

plt.tight_layout()
plt.show()
# Out:
# Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...
#
# Avvio valutazione robustezza su 13 configurazioni...
# ------------------------------------------------------------
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Shift -0.90 | Reward:  1681.50 +/-  50.43
# Shift -0.60 | Reward:  1678.74 +/-  50.36
# Shift -0.30 | Reward:  1688.20 +/-  45.50
# Shift +0.00 | Reward:  1668.06 +/-  44.85
# Shift +0.30 | Reward:  1685.77 +/-  54.43
# Shift +0.60 | Reward:  1683.75 +/-  49.34
# Shift +0.90 | Reward:  1672.16 +/-  45.55
# Shift +1.20 | Reward:  1313.14 +/- 151.48
# Shift +1.50 | Reward:  1427.73 +/- 185.30
# Shift +1.80 | Reward:   890.68 +/-  20.07
# Shift +2.10 | Reward:   477.17 +/-   8.69
# Shift +2.40 | Reward:   391.61 +/-   1.63
# Shift +2.70 | Reward:   341.31 +/-   1.49

# %%
# RENDERING THE TRAINED AGENT

import gymnasium as gym
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import time

# --- CONFIGURATION ---
# Use the same 'model_name' from your previous cell, or type it manually here
# e.g., model_name = "SAC_doraemon_0"
env_to_render = 'CustomHopper-source-v0' # Change to 'target' to see the Real/Shifted env

# 1. Setup the Environment with Rendering Enabled
# render_mode="human" creates the popup window
env = DummyVecEnv([lambda: gym.make(env_to_render, render_mode="human")])

# 2. Load the Normalization Statistics (CRITICAL)
# If you skip this, the agent will see "wrong" numbers and fail immediately
norm_path = f"./logs/{model_name}_vecnormalize.pkl"
try:
    env = VecNormalize.load(norm_path, env)
    # We must disable training and reward normalization for inference
    env.training = False
    env.norm_reward = False
    print(f"Loaded Normalization stats from {norm_path}")
except FileNotFoundError:
    print("Warning: No normalization stats found. Running with RAW observations.")

# 3. Load the Trained Model
model_path = f"./logs/{model_name}_model.zip"
model = SAC.load(model_path)

# 4. The Simulation Loop
print(f"Starting rendering for {env_to_render}...")
obs = env.reset()

try:
    # Run for 1000 steps (or until you stop it)
    for _ in range(1000):
        # Get the action from the agent
        action, _ = model.predict(obs, deterministic=True)
        
        # Step the environment
        obs, rewards, dones, info = env.step(action)
        
        # Render the frame
        env.render()
        
        # Slow down slightly so you can see what's happening (Macs run this very fast)
        time.sleep(0.02)
        
        if dones[0]:
            print("Agent fell over! Resetting...")
            obs = env.reset()
            # time.sleep(1.0) # Pause briefly on failure if you want to see the crash

except KeyboardInterrupt:
    print("Simulation stopped by user.")
finally:
    env.close()

# %%
env = gym.make("CustomHopper-shift-v0", mass_shift=shift)
env.unwrapped.model.geom_friction

# %%
from env.custom_hopper import CustomHopper
import gymnasium as gym

env = CustomHopper(domain="source")

print("Body Masses:")
for i in range(env.unwrapped.model.body_mass.shape[0]):
    print(f"Body {env.unwrapped.model.body(i).name} mass: {env.unwrapped.model.body_mass[i]}")

print ("\nFriction coefficients:")
for i in range(env.unwrapped.model.geom_friction.shape[0]):
    print(f"Body {env.unwrapped.model.geom(i).name} friction: {env.unwrapped.model.geom_friction[i]}")

print ("\nDamping coefficients:")
for i in range(env.unwrapped.model.dof_damping.shape[0]):
    print(f"Body {env.unwrapped.model.joint(i).name} damping: {env.unwrapped.model.dof_damping[i]}")
