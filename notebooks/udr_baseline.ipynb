# %%
import sys
import os
sys.path.append(os.path.abspath('../')) # Point to project root

# %%
import importlib
import modules.beta_trainer
import modules.utils
import modules.callbacks
import modules.env
import env.custom_hopper

# Force reload of the modules you changed
importlib.reload(modules.env)
importlib.reload(modules.callbacks)
importlib.reload(modules.utils)
importlib.reload(modules.beta_trainer)
importlib.reload(env.custom_hopper)

# Re-import the specific functions into the global namespace
from modules.beta_trainer import train_agent
from modules.utils import *
from env.custom_hopper import *

print("Modules reloaded successfully!")
# Out:
# Modules reloaded successfully!
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/gymnasium/envs/registration.py:644: UserWarning: WARN: Overriding environment CustomHopper-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/gymnasium/envs/registration.py:644: UserWarning: WARN: Overriding environment CustomHopper-source-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/gymnasium/envs/registration.py:644: UserWarning: WARN: Overriding environment CustomHopper-target-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/gymnasium/envs/registration.py:644: UserWarning: WARN: Overriding environment CustomHopper-shift-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
from modules.beta_trainer import train_agent
from modules.utils import *
from env.custom_hopper import *

# %%
config = {
    'env_id': 'CustomHopper-source-v0',
    'algo': 'sac',
    'seed': 42,
    'timesteps': 1_000_000,
    'n_envs': 4,
    'vectorize': True,
    'normalize': True, 
    'lr': 1e-3,
    'gradient_steps': 2,
    'train_freq': 1,
    
    'mode': "udr"

}

# %%
# Training
train_agent(config, model_name="udr_baseline_2x", log_dir="./logs/udr_experiment_2x/")
# Out:
# Training with mode: udr
# --- STARTING NEW TRAINING ---
# Using cpu device
# Skipping DoraemonCallback for mode: udr
# Logging to ./tensorboard_logs/SAC_30
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.2     |
# |    ep_rew_mean     | 9.61     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 1185     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | -2.28    |
# |    critic_loss     | 6.25     |
# |    ent_coef        | 1        |
# |    ent_coef_loss   | -0.00249 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2        |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 17       |
# |    ep_rew_mean     | 10.1     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 573      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 172      |
# | train/             |          |
# |    actor_loss      | -4.52    |
# |    critic_loss     | 0.564    |
# |    ent_coef        | 0.968    |
# |    ent_coef_loss   | -0.163   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 34       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | 10.3     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 418      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 284      |
# | train/             |          |
# |    actor_loss      | -4.91    |
# |    critic_loss     | 0.393    |
# |    ent_coef        | 0.915    |
# |    ent_coef_loss   | -0.445   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 90       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | 14.5     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 319      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 388      |
# | train/             |          |
# |    actor_loss      | -5.16    |
# |    critic_loss     | 0.36     |
# |    ent_coef        | 0.869    |
# |    ent_coef_loss   | -0.708   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 142      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.4     |
# |    ep_rew_mean     | 16.3     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 273      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 484      |
# | train/             |          |
# |    actor_loss      | -5.63    |
# |    critic_loss     | 0.369    |
# |    ent_coef        | 0.828    |
# |    ent_coef_loss   | -0.944   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 190      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.1     |
# |    ep_rew_mean     | 17.1     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 270      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 632      |
# | train/             |          |
# |    actor_loss      | -6.15    |
# |    critic_loss     | 0.207    |
# |    ent_coef        | 0.769    |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 264      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.1     |
# |    ep_rew_mean     | 17.3     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 268      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 720      |
# | train/             |          |
# |    actor_loss      | -6.08    |
# |    critic_loss     | 0.169    |
# |    ent_coef        | 0.736    |
# |    ent_coef_loss   | -1.52    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 308      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25       |
# |    ep_rew_mean     | 19.6     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 270      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 948      |
# | train/             |          |
# |    actor_loss      | -6.94    |
# |    critic_loss     | 0.154    |
# |    ent_coef        | 0.657    |
# |    ent_coef_loss   | -2.09    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 422      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.4     |
# |    ep_rew_mean     | 20.4     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 273      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1052     |
# | train/             |          |
# |    actor_loss      | -7.25    |
# |    critic_loss     | 0.241    |
# |    ent_coef        | 0.624    |
# |    ent_coef_loss   | -2.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 474      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.2     |
# |    ep_rew_mean     | 25.5     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 275      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1168     |
# | train/             |          |
# |    actor_loss      | -7.21    |
# |    critic_loss     | 0.379    |
# |    ent_coef        | 0.589    |
# |    ent_coef_loss   | -2.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 532      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 29.2     |
# |    ep_rew_mean     | 27       |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 272      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1340     |
# | train/             |          |
# |    actor_loss      | -7.97    |
# |    critic_loss     | 0.342    |
# |    ent_coef        | 0.542    |
# |    ent_coef_loss   | -2.96    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 618      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31.8     |
# |    ep_rew_mean     | 33.7     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 265      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 1792     |
# | train/             |          |
# |    actor_loss      | -9.4     |
# |    critic_loss     | 0.38     |
# |    ent_coef        | 0.435    |
# |    ent_coef_loss   | -3.86    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 844      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.8     |
# |    ep_rew_mean     | 43.4     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 263      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2112     |
# | train/             |          |
# |    actor_loss      | -10.3    |
# |    critic_loss     | 0.313    |
# |    ent_coef        | 0.375    |
# |    ent_coef_loss   | -4.31    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1004     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.3     |
# |    ep_rew_mean     | 58.3     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 271      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2704     |
# | train/             |          |
# |    actor_loss      | -12.9    |
# |    critic_loss     | 0.394    |
# |    ent_coef        | 0.288    |
# |    ent_coef_loss   | -5       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1300     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.7     |
# |    ep_rew_mean     | 74.5     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 274      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 3296     |
# | train/             |          |
# |    actor_loss      | -15.5    |
# |    critic_loss     | 0.529    |
# |    ent_coef        | 0.224    |
# |    ent_coef_loss   | -5.48    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1596     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.7     |
# |    ep_rew_mean     | 86.3     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 278      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 3688     |
# | train/             |          |
# |    actor_loss      | -17.1    |
# |    critic_loss     | 0.388    |
# |    ent_coef        | 0.192    |
# |    ent_coef_loss   | -5       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1792     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.7     |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 281      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 4244     |
# | train/             |          |
# |    actor_loss      | -19.4    |
# |    critic_loss     | 0.514    |
# |    ent_coef        | 0.155    |
# |    ent_coef_loss   | -5.78    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2070     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 63.5     |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 283      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 4672     |
# | train/             |          |
# |    actor_loss      | -21.6    |
# |    critic_loss     | 0.821    |
# |    ent_coef        | 0.132    |
# |    ent_coef_loss   | -5.48    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2284     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.6     |
# |    ep_rew_mean     | 123      |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 286      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 5160     |
# | train/             |          |
# |    actor_loss      | -24      |
# |    critic_loss     | 0.772    |
# |    ent_coef        | 0.111    |
# |    ent_coef_loss   | -5.24    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2528     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 69.2     |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 287      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 5632     |
# | train/             |          |
# |    actor_loss      | -26      |
# |    critic_loss     | 2.21     |
# |    ent_coef        | 0.095    |
# |    ent_coef_loss   | -4.89    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2764     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 71.9     |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 286      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 6196     |
# | train/             |          |
# |    actor_loss      | -29.6    |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.0799   |
# |    ent_coef_loss   | -4.14    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3046     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 73.8     |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 288      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 6584     |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 2.21     |
# |    ent_coef        | 0.0719   |
# |    ent_coef_loss   | -3.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3240     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 76.3     |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 288      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 7092     |
# | train/             |          |
# |    actor_loss      | -34.1    |
# |    critic_loss     | 2.3      |
# |    ent_coef        | 0.0632   |
# |    ent_coef_loss   | -3.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3494     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 77.5     |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 289      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 7620     |
# | train/             |          |
# |    actor_loss      | -36.5    |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.0566   |
# |    ent_coef_loss   | -2.83    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3758     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.9     |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 290      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 8044     |
# | train/             |          |
# |    actor_loss      | -38.8    |
# |    critic_loss     | 2.99     |
# |    ent_coef        | 0.0521   |
# |    ent_coef_loss   | -0.952   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3970     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 84.1     |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 289      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 8564     |
# | train/             |          |
# |    actor_loss      | -41.9    |
# |    critic_loss     | 2.93     |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | -2.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4230     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.5     |
# |    ep_rew_mean     | 194      |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 288      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 8964     |
# | train/             |          |
# |    actor_loss      | -43.1    |
# |    critic_loss     | 3.36     |
# |    ent_coef        | 0.0454   |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4430     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.5     |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 286      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 9492     |
# | train/             |          |
# |    actor_loss      | -46.4    |
# |    critic_loss     | 4.38     |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | -1.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4694     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.4     |
# |    ep_rew_mean     | 219      |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 287      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 9964     |
# | train/             |          |
# |    actor_loss      | -48.2    |
# |    critic_loss     | 2.02     |
# |    ent_coef        | 0.0419   |
# |    ent_coef_loss   | -0.704   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4930     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 98.6     |
# |    ep_rew_mean     | 230      |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 278      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 10496    |
# | train/             |          |
# |    actor_loss      | -51.3    |
# |    critic_loss     | 2.46     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | -0.526   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5196     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | 241      |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 276      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 10900    |
# | train/             |          |
# |    actor_loss      | -52.8    |
# |    critic_loss     | 1.85     |
# |    ent_coef        | 0.0396   |
# |    ent_coef_loss   | -1.42    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5398     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 106      |
# |    ep_rew_mean     | 254      |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 277      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 11452    |
# | train/             |          |
# |    actor_loss      | -54.4    |
# |    critic_loss     | 1.94     |
# |    ent_coef        | 0.0388   |
# |    ent_coef_loss   | -0.276   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5674     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 110      |
# |    ep_rew_mean     | 266      |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 276      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 12004    |
# | train/             |          |
# |    actor_loss      | -57.9    |
# |    critic_loss     | 1.66     |
# |    ent_coef        | 0.0386   |
# |    ent_coef_loss   | 0.383    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5950     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 113      |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 278      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 12556    |
# | train/             |          |
# |    actor_loss      | -60.6    |
# |    critic_loss     | 2.39     |
# |    ent_coef        | 0.0379   |
# |    ent_coef_loss   | 1.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6226     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 116      |
# |    ep_rew_mean     | 288      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 280      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 13164    |
# | train/             |          |
# |    actor_loss      | -63.8    |
# |    critic_loss     | 1.9      |
# |    ent_coef        | 0.0384   |
# |    ent_coef_loss   | -0.182   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6530     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 301      |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 281      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 13604    |
# | train/             |          |
# |    actor_loss      | -64.3    |
# |    critic_loss     | 2.38     |
# |    ent_coef        | 0.0391   |
# |    ent_coef_loss   | -0.353   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6750     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 123      |
# |    ep_rew_mean     | 309      |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 282      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 13968    |
# | train/             |          |
# |    actor_loss      | -66.4    |
# |    critic_loss     | 2.26     |
# |    ent_coef        | 0.0408   |
# |    ent_coef_loss   | -0.0565  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6932     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 317      |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 284      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 14520    |
# | train/             |          |
# |    actor_loss      | -69      |
# |    critic_loss     | 3.93     |
# |    ent_coef        | 0.0428   |
# |    ent_coef_loss   | 0.389    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7208     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 319      |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 285      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 15020    |
# | train/             |          |
# |    actor_loss      | -69.7    |
# |    critic_loss     | 2.27     |
# |    ent_coef        | 0.0431   |
# |    ent_coef_loss   | -0.0255  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7458     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 320      |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 286      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 15444    |
# | train/             |          |
# |    actor_loss      | -71.6    |
# |    critic_loss     | 2.09     |
# |    ent_coef        | 0.0443   |
# |    ent_coef_loss   | -0.86    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7670     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 323      |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 288      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 15980    |
# | train/             |          |
# |    actor_loss      | -75.1    |
# |    critic_loss     | 2.73     |
# |    ent_coef        | 0.0439   |
# |    ent_coef_loss   | -0.521   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7938     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 323      |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 289      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 16516    |
# | train/             |          |
# |    actor_loss      | -75.9    |
# |    critic_loss     | 3.92     |
# |    ent_coef        | 0.0459   |
# |    ent_coef_loss   | 0.501    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8206     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 323      |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 289      |
# |    time_elapsed    | 58       |
# |    total_timesteps | 16908    |
# | train/             |          |
# |    actor_loss      | -78.7    |
# |    critic_loss     | 3.48     |
# |    ent_coef        | 0.0471   |
# |    ent_coef_loss   | 0.664    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8402     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 324      |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 290      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 17372    |
# | train/             |          |
# |    actor_loss      | -80.5    |
# |    critic_loss     | 3.09     |
# |    ent_coef        | 0.0484   |
# |    ent_coef_loss   | -0.462   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8634     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 324      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 291      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 17780    |
# | train/             |          |
# |    actor_loss      | -84.4    |
# |    critic_loss     | 4.3      |
# |    ent_coef        | 0.0496   |
# |    ent_coef_loss   | -0.439   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8838     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | 323      |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 292      |
# |    time_elapsed    | 62       |
# |    total_timesteps | 18240    |
# | train/             |          |
# |    actor_loss      | -84.8    |
# |    critic_loss     | 3.81     |
# |    ent_coef        | 0.0507   |
# |    ent_coef_loss   | -0.983   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9068     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | 323      |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 293      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 18720    |
# | train/             |          |
# |    actor_loss      | -85.9    |
# |    critic_loss     | 2.91     |
# |    ent_coef        | 0.0482   |
# |    ent_coef_loss   | -0.603   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9308     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | 321      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 294      |
# |    time_elapsed    | 65       |
# |    total_timesteps | 19188    |
# | train/             |          |
# |    actor_loss      | -85.9    |
# |    critic_loss     | 7.25     |
# |    ent_coef        | 0.0484   |
# |    ent_coef_loss   | -0.246   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9542     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | 321      |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 295      |
# |    time_elapsed    | 66       |
# |    total_timesteps | 19744    |
# | train/             |          |
# |    actor_loss      | -90.2    |
# |    critic_loss     | 3.68     |
# |    ent_coef        | 0.0476   |
# |    ent_coef_loss   | 0.787    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9820     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 317      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 295      |
# |    time_elapsed    | 67       |
# |    total_timesteps | 20040    |
# | train/             |          |
# |    actor_loss      | -90.9    |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.046    |
# |    ent_coef_loss   | 1.09     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9968     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | 309      |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 296      |
# |    time_elapsed    | 68       |
# |    total_timesteps | 20332    |
# | train/             |          |
# |    actor_loss      | -90.4    |
# |    critic_loss     | 5.92     |
# |    ent_coef        | 0.0474   |
# |    ent_coef_loss   | -0.34    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10114    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | 309      |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 297      |
# |    time_elapsed    | 69       |
# |    total_timesteps | 20796    |
# | train/             |          |
# |    actor_loss      | -94      |
# |    critic_loss     | 3.82     |
# |    ent_coef        | 0.0489   |
# |    ent_coef_loss   | -0.194   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10346    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 116      |
# |    ep_rew_mean     | 305      |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 297      |
# |    time_elapsed    | 71       |
# |    total_timesteps | 21172    |
# | train/             |          |
# |    actor_loss      | -94.7    |
# |    critic_loss     | 4.87     |
# |    ent_coef        | 0.0499   |
# |    ent_coef_loss   | 1.27     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10534    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 116      |
# |    ep_rew_mean     | 304      |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 298      |
# |    time_elapsed    | 72       |
# |    total_timesteps | 21612    |
# | train/             |          |
# |    actor_loss      | -95.7    |
# |    critic_loss     | 4.09     |
# |    ent_coef        | 0.0516   |
# |    ent_coef_loss   | 0.132    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10754    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 115      |
# |    ep_rew_mean     | 302      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 298      |
# |    time_elapsed    | 73       |
# |    total_timesteps | 22100    |
# | train/             |          |
# |    actor_loss      | -96.4    |
# |    critic_loss     | 4.62     |
# |    ent_coef        | 0.0521   |
# |    ent_coef_loss   | 0.942    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10998    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 115      |
# |    ep_rew_mean     | 302      |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 298      |
# |    time_elapsed    | 75       |
# |    total_timesteps | 22524    |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 6.28     |
# |    ent_coef        | 0.0514   |
# |    ent_coef_loss   | -0.25    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11210    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 116      |
# |    ep_rew_mean     | 303      |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 298      |
# |    time_elapsed    | 77       |
# |    total_timesteps | 23032    |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 4.74     |
# |    ent_coef        | 0.054    |
# |    ent_coef_loss   | -0.113   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11464    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | 304      |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 298      |
# |    time_elapsed    | 79       |
# |    total_timesteps | 23664    |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 5.87     |
# |    ent_coef        | 0.0557   |
# |    ent_coef_loss   | 0.349    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 11780    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | 305      |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 299      |
# |    time_elapsed    | 80       |
# |    total_timesteps | 24196    |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 6.69     |
# |    ent_coef        | 0.0579   |
# |    ent_coef_loss   | -0.195   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12046    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 116      |
# |    ep_rew_mean     | 300      |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 299      |
# |    time_elapsed    | 82       |
# |    total_timesteps | 24616    |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 4.51     |
# |    ent_coef        | 0.0607   |
# |    ent_coef_loss   | 0.525    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12256    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | 302      |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 300      |
# |    time_elapsed    | 83       |
# |    total_timesteps | 25124    |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 5.7      |
# |    ent_coef        | 0.0614   |
# |    ent_coef_loss   | 1.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12510    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | 302      |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 301      |
# |    time_elapsed    | 85       |
# |    total_timesteps | 25640    |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 7.42     |
# |    ent_coef        | 0.0652   |
# |    ent_coef_loss   | -0.382   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12768    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 117      |
# |    ep_rew_mean     | 302      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 301      |
# |    time_elapsed    | 86       |
# |    total_timesteps | 26212    |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 5.5      |
# |    ent_coef        | 0.0666   |
# |    ent_coef_loss   | 0.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13054    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 308      |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 301      |
# |    time_elapsed    | 89       |
# |    total_timesteps | 26928    |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 9.86     |
# |    ent_coef        | 0.0667   |
# |    ent_coef_loss   | 0.042    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13412    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 306      |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 302      |
# |    time_elapsed    | 90       |
# |    total_timesteps | 27432    |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 7.84     |
# |    ent_coef        | 0.0669   |
# |    ent_coef_loss   | -0.0522  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13664    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 118      |
# |    ep_rew_mean     | 305      |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 302      |
# |    time_elapsed    | 92       |
# |    total_timesteps | 27860    |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 7        |
# |    ent_coef        | 0.0666   |
# |    ent_coef_loss   | 0.151    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13878    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 305      |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 302      |
# |    time_elapsed    | 93       |
# |    total_timesteps | 28308    |
# | train/             |          |
# |    actor_loss      | -117     |
# |    critic_loss     | 6.35     |
# |    ent_coef        | 0.07     |
# |    ent_coef_loss   | 0.0984   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14102    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 306      |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 303      |
# |    time_elapsed    | 94       |
# |    total_timesteps | 28748    |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 23.7     |
# |    ent_coef        | 0.0699   |
# |    ent_coef_loss   | -0.659   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14322    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 307      |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 303      |
# |    time_elapsed    | 96       |
# |    total_timesteps | 29240    |
# | train/             |          |
# |    actor_loss      | -123     |
# |    critic_loss     | 6.54     |
# |    ent_coef        | 0.0704   |
# |    ent_coef_loss   | 0.362    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14568    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 310      |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 304      |
# |    time_elapsed    | 97       |
# |    total_timesteps | 29828    |
# | train/             |          |
# |    actor_loss      | -123     |
# |    critic_loss     | 6.12     |
# |    ent_coef        | 0.0679   |
# |    ent_coef_loss   | -0.499   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 14862    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 312      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 305      |
# |    time_elapsed    | 99       |
# |    total_timesteps | 30284    |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 27.3     |
# |    ent_coef        | 0.0687   |
# |    ent_coef_loss   | 0.248    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15090    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 312      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 305      |
# |    time_elapsed    | 100      |
# |    total_timesteps | 30744    |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 7.95     |
# |    ent_coef        | 0.0697   |
# |    ent_coef_loss   | -0.805   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15320    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 312      |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 306      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 31184    |
# | train/             |          |
# |    actor_loss      | -125     |
# |    critic_loss     | 8.52     |
# |    ent_coef        | 0.0702   |
# |    ent_coef_loss   | 0.93     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15540    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 119      |
# |    ep_rew_mean     | 314      |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 306      |
# |    time_elapsed    | 103      |
# |    total_timesteps | 31708    |
# | train/             |          |
# |    actor_loss      | -127     |
# |    critic_loss     | 8.54     |
# |    ent_coef        | 0.0701   |
# |    ent_coef_loss   | -0.255   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 15802    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 121      |
# |    ep_rew_mean     | 322      |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 307      |
# |    time_elapsed    | 104      |
# |    total_timesteps | 32212    |
# | train/             |          |
# |    actor_loss      | -128     |
# |    critic_loss     | 8.49     |
# |    ent_coef        | 0.069    |
# |    ent_coef_loss   | 0.0128   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16054    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 122      |
# |    ep_rew_mean     | 327      |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 308      |
# |    time_elapsed    | 105      |
# |    total_timesteps | 32644    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 9.46     |
# |    ent_coef        | 0.0704   |
# |    ent_coef_loss   | 0.294    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16270    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 124      |
# |    ep_rew_mean     | 337      |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 308      |
# |    time_elapsed    | 107      |
# |    total_timesteps | 33336    |
# | train/             |          |
# |    actor_loss      | -131     |
# |    critic_loss     | 6.2      |
# |    ent_coef        | 0.0702   |
# |    ent_coef_loss   | -0.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16616    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | 346      |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 309      |
# |    time_elapsed    | 109      |
# |    total_timesteps | 33828    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 8.52     |
# |    ent_coef        | 0.0718   |
# |    ent_coef_loss   | 0.175    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16862    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 127      |
# |    ep_rew_mean     | 348      |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 309      |
# |    time_elapsed    | 110      |
# |    total_timesteps | 34380    |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 6.94     |
# |    ent_coef        | 0.0724   |
# |    ent_coef_loss   | -0.816   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17138    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 128      |
# |    ep_rew_mean     | 351      |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 310      |
# |    time_elapsed    | 112      |
# |    total_timesteps | 34896    |
# | train/             |          |
# |    actor_loss      | -133     |
# |    critic_loss     | 9.96     |
# |    ent_coef        | 0.0724   |
# |    ent_coef_loss   | 0.645    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17396    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 357      |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 311      |
# |    time_elapsed    | 114      |
# |    total_timesteps | 35656    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 10.6     |
# |    ent_coef        | 0.0766   |
# |    ent_coef_loss   | -0.211   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17776    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 357      |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 311      |
# |    time_elapsed    | 115      |
# |    total_timesteps | 36096    |
# | train/             |          |
# |    actor_loss      | -136     |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 0.0756   |
# |    ent_coef_loss   | -0.351   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17996    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 129      |
# |    ep_rew_mean     | 357      |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 312      |
# |    time_elapsed    | 116      |
# |    total_timesteps | 36508    |
# | train/             |          |
# |    actor_loss      | -138     |
# |    critic_loss     | 9.33     |
# |    ent_coef        | 0.0773   |
# ...
# |    actor_loss      | -219     |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0435   |
# |    ent_coef_loss   | -0.513   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 484330   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 288      |
# |    ep_rew_mean     | 887      |
# | time/              |          |
# |    episodes        | 3716     |
# |    fps             | 338      |
# |    time_elapsed    | 2865     |
# |    total_timesteps | 969392   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 13.2     |
# |    ent_coef        | 0.0424   |
# |    ent_coef_loss   | -0.622   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 484644   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 281      |
# |    ep_rew_mean     | 864      |
# | time/              |          |
# |    episodes        | 3720     |
# |    fps             | 338      |
# |    time_elapsed    | 2869     |
# |    total_timesteps | 970932   |
# | train/             |          |
# |    actor_loss      | -218     |
# |    critic_loss     | 12       |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | 0.577    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 485414   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 286      |
# |    ep_rew_mean     | 881      |
# | time/              |          |
# |    episodes        | 3724     |
# |    fps             | 338      |
# |    time_elapsed    | 2872     |
# |    total_timesteps | 971936   |
# | train/             |          |
# |    actor_loss      | -223     |
# |    critic_loss     | 12.7     |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | 0.0793   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 485916   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 290      |
# |    ep_rew_mean     | 898      |
# | time/              |          |
# |    episodes        | 3728     |
# |    fps             | 338      |
# |    time_elapsed    | 2876     |
# |    total_timesteps | 973132   |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 8.43     |
# |    ent_coef        | 0.0417   |
# |    ent_coef_loss   | -0.124   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 486514   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 292      |
# |    ep_rew_mean     | 904      |
# | time/              |          |
# |    episodes        | 3732     |
# |    fps             | 338      |
# |    time_elapsed    | 2879     |
# |    total_timesteps | 974324   |
# | train/             |          |
# |    actor_loss      | -217     |
# |    critic_loss     | 8.63     |
# |    ent_coef        | 0.0422   |
# |    ent_coef_loss   | 0.187    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 487110   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 913      |
# | time/              |          |
# |    episodes        | 3736     |
# |    fps             | 338      |
# |    time_elapsed    | 2881     |
# |    total_timesteps | 974976   |
# | train/             |          |
# |    actor_loss      | -222     |
# |    critic_loss     | 10.5     |
# |    ent_coef        | 0.0431   |
# |    ent_coef_loss   | 0.173    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 487436   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 936      |
# | time/              |          |
# |    episodes        | 3740     |
# |    fps             | 338      |
# |    time_elapsed    | 2885     |
# |    total_timesteps | 976464   |
# | train/             |          |
# |    actor_loss      | -224     |
# |    critic_loss     | 9.33     |
# |    ent_coef        | 0.0443   |
# |    ent_coef_loss   | -0.31    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 488180   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | 936      |
# | time/              |          |
# |    episodes        | 3744     |
# |    fps             | 338      |
# |    time_elapsed    | 2888     |
# |    total_timesteps | 977512   |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 7.72     |
# |    ent_coef        | 0.0433   |
# |    ent_coef_loss   | -0.265   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 488704   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 916      |
# | time/              |          |
# |    episodes        | 3748     |
# |    fps             | 338      |
# |    time_elapsed    | 2891     |
# |    total_timesteps | 978504   |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.0431   |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 489200   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 294      |
# |    ep_rew_mean     | 911      |
# | time/              |          |
# |    episodes        | 3752     |
# |    fps             | 338      |
# |    time_elapsed    | 2894     |
# |    total_timesteps | 979392   |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 14.1     |
# |    ent_coef        | 0.0435   |
# |    ent_coef_loss   | -0.284   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 489644   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 921      |
# | time/              |          |
# |    episodes        | 3756     |
# |    fps             | 338      |
# |    time_elapsed    | 2898     |
# |    total_timesteps | 980936   |
# | train/             |          |
# |    actor_loss      | -220     |
# |    critic_loss     | 9.57     |
# |    ent_coef        | 0.0443   |
# |    ent_coef_loss   | 0.311    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 490416   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 292      |
# |    ep_rew_mean     | 913      |
# | time/              |          |
# |    episodes        | 3760     |
# |    fps             | 338      |
# |    time_elapsed    | 2902     |
# |    total_timesteps | 982196   |
# | train/             |          |
# |    actor_loss      | -219     |
# |    critic_loss     | 8.55     |
# |    ent_coef        | 0.0475   |
# |    ent_coef_loss   | 0.404    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 491046   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 925      |
# | time/              |          |
# |    episodes        | 3764     |
# |    fps             | 338      |
# |    time_elapsed    | 2905     |
# |    total_timesteps | 983428   |
# | train/             |          |
# |    actor_loss      | -218     |
# |    critic_loss     | 18       |
# |    ent_coef        | 0.0411   |
# |    ent_coef_loss   | 0.595    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 491662   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 921      |
# | time/              |          |
# |    episodes        | 3768     |
# |    fps             | 338      |
# |    time_elapsed    | 2911     |
# |    total_timesteps | 985188   |
# | train/             |          |
# |    actor_loss      | -218     |
# |    critic_loss     | 11.2     |
# |    ent_coef        | 0.0408   |
# |    ent_coef_loss   | 0.639    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 492542   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 943      |
# | time/              |          |
# |    episodes        | 3772     |
# |    fps             | 338      |
# |    time_elapsed    | 2914     |
# |    total_timesteps | 986192   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 15.1     |
# |    ent_coef        | 0.0435   |
# |    ent_coef_loss   | -0.514   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 493044   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 301      |
# |    ep_rew_mean     | 946      |
# | time/              |          |
# |    episodes        | 3776     |
# |    fps             | 338      |
# |    time_elapsed    | 2916     |
# |    total_timesteps | 986896   |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 16.8     |
# |    ent_coef        | 0.039    |
# |    ent_coef_loss   | 0.362    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 493396   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | 936      |
# | time/              |          |
# |    episodes        | 3780     |
# |    fps             | 338      |
# |    time_elapsed    | 2921     |
# |    total_timesteps | 988640   |
# | train/             |          |
# |    actor_loss      | -219     |
# |    critic_loss     | 11.5     |
# |    ent_coef        | 0.0415   |
# |    ent_coef_loss   | 0.742    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 494268   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 302      |
# |    ep_rew_mean     | 946      |
# | time/              |          |
# |    episodes        | 3784     |
# |    fps             | 338      |
# |    time_elapsed    | 2925     |
# |    total_timesteps | 989960   |
# | train/             |          |
# |    actor_loss      | -213     |
# |    critic_loss     | 13.9     |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | 0.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 494928   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 306      |
# |    ep_rew_mean     | 966      |
# | time/              |          |
# |    episodes        | 3788     |
# |    fps             | 338      |
# |    time_elapsed    | 2928     |
# |    total_timesteps | 991088   |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 38.8     |
# |    ent_coef        | 0.0433   |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495492   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 298      |
# |    ep_rew_mean     | 936      |
# | time/              |          |
# |    episodes        | 3792     |
# |    fps             | 338      |
# |    time_elapsed    | 2931     |
# |    total_timesteps | 992052   |
# | train/             |          |
# |    actor_loss      | -216     |
# |    critic_loss     | 11.4     |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | 0.348    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495974   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 296      |
# |    ep_rew_mean     | 932      |
# | time/              |          |
# |    episodes        | 3796     |
# |    fps             | 338      |
# |    time_elapsed    | 2933     |
# |    total_timesteps | 992888   |
# | train/             |          |
# |    actor_loss      | -218     |
# |    critic_loss     | 14.5     |
# |    ent_coef        | 0.0428   |
# |    ent_coef_loss   | 0.0839   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 496392   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | 921      |
# | time/              |          |
# |    episodes        | 3800     |
# |    fps             | 338      |
# |    time_elapsed    | 2937     |
# |    total_timesteps | 994300   |
# | train/             |          |
# |    actor_loss      | -223     |
# |    critic_loss     | 10.4     |
# |    ent_coef        | 0.0414   |
# |    ent_coef_loss   | 0.515    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 497098   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 292      |
# |    ep_rew_mean     | 917      |
# | time/              |          |
# |    episodes        | 3804     |
# |    fps             | 338      |
# |    time_elapsed    | 2940     |
# |    total_timesteps | 995368   |
# | train/             |          |
# |    actor_loss      | -221     |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.0395   |
# |    ent_coef_loss   | 0.167    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 497632   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 288      |
# |    ep_rew_mean     | 905      |
# | time/              |          |
# |    episodes        | 3808     |
# |    fps             | 338      |
# |    time_elapsed    | 2943     |
# |    total_timesteps | 996404   |
# | train/             |          |
# |    actor_loss      | -219     |
# |    critic_loss     | 16.3     |
# |    ent_coef        | 0.0413   |
# |    ent_coef_loss   | 0.805    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498150   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 288      |
# |    ep_rew_mean     | 905      |
# | time/              |          |
# |    episodes        | 3812     |
# |    fps             | 338      |
# |    time_elapsed    | 2945     |
# |    total_timesteps | 997104   |
# | train/             |          |
# |    actor_loss      | -215     |
# |    critic_loss     | 24.8     |
# |    ent_coef        | 0.0418   |
# |    ent_coef_loss   | 0.621    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498500   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 287      |
# |    ep_rew_mean     | 904      |
# | time/              |          |
# |    episodes        | 3816     |
# |    fps             | 338      |
# |    time_elapsed    | 2949     |
# |    total_timesteps | 998292   |
# | train/             |          |
# |    actor_loss      | -214     |
# |    critic_loss     | 10.5     |
# |    ent_coef        | 0.0414   |
# |    ent_coef_loss   | 0.539    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499094   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 290      |
# |    ep_rew_mean     | 910      |
# | time/              |          |
# |    episodes        | 3820     |
# |    fps             | 338      |
# |    time_elapsed    | 2953     |
# |    total_timesteps | 999724   |
# | train/             |          |
# |    actor_loss      | -222     |
# |    critic_loss     | 11.5     |
# |    ent_coef        | 0.0444   |
# |    ent_coef_loss   | -0.427   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499810   |
# ---------------------------------
# (<stable_baselines3.sac.sac.SAC at 0x10e839670>,
#  <stable_baselines3.common.vec_env.vec_normalize.VecNormalize at 0x10ddd7190>,
#  None)

# %%
# ONLY USE IF TRAINING WAS INTERRUPTED AND YOU HAVE CHECKPOINTS

import os
import re

# CHECKPOINT VERIFICATION

checkpoint_dir = "./logs/checkpoints"
if os.path.exists(checkpoint_dir):
    print("Files found:", os.listdir(checkpoint_dir))
else:
    print("No checkpoints found! The interrupt save didn't work.")


# RESUME TRAINING FROM CHECKPOINT

# 1. Find the latest checkpoint step
log_dir = "./logs/"
ckpt_dir = os.path.join(log_dir, "checkpoints")

latest_step = None
if os.path.exists(ckpt_dir):
    # regex to find numbers in filenames
    steps = [int(re.search(r'\d+', f).group()) for f in os.listdir(ckpt_dir) if "model_" in f]
    if steps:
        latest_step = max(steps)

print(f"Resuming from step: {latest_step}")

# 2. Resume Training
if latest_step is not None:
    # Pass the step number to resume_step
    model, env, doraemon_cb = train_agent(config, log_dir=log_dir, resume_step=latest_step)
else:
    print("Could not find a checkpoint to resume.")

# %%
# Used to visualize training metrics through TensorBoard
! tensorboard --logdir ./tensorboard_logs/

# Note: if you want to run Tensorboard from terminal, simply use the command above
# Out:
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/tensorboard/default.py:30: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# TensorFlow installation not found - running with reduced feature set.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.20.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
import json
import numpy as np

class DoraemonMockCallback:
    def __init__(self, json_path):
        # Load the JSON data
        with open(json_path, 'r') as f:
            data = json.load(f)
        
        # Extract the history
        self.history = data.get("history", {}) 
        
        print(f"Data loaded. Updates found: {len(self.history.get('entropy', []))}")


doraemon_cb = DoraemonMockCallback('logs/doraemon_state_20000000.json')

plot_doraemon_dynamics(doraemon_cb)
# Out:
# Data loaded. Updates found: 541

# %%
from modules.utils import *
from stable_baselines3 import SAC

# Define the raw environments
source_env = gym.make('CustomHopper-source-v0')
target_env = gym.make('CustomHopper-target-v0')

# Reconstruct the model name used in training
model_name = f"{config['algo']}_doraemon_{config['seed']}"
model_name = "final"

print("Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...")
model = SAC.load("./logs/udr_experiment/udr_baseline", device="cpu")

# Run evaluation
evaluate_sim2real(model, source_env, target_env, log_dir="./logs/", model_name=model_name)
# Out:
# Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...
# Loaded Normalization stats from ./logs//final_vecnormalize.pkl
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# --- Evaluating on SOURCE Env (Simulation) ---
# Reward: 43.91 +/- 0.93
# Length: 25.70 +/- 0.56 steps
#
# --- Evaluating on TARGET Env (Real/Shifted) ---
# Reward: 46.95 +/- 1.24
# Length: 28.70 +/- 0.78 steps
# (np.float64(43.90747263431549), np.float64(46.9465738594532))

# %%
import matplotlib.pyplot as plt
import numpy as np
import gymnasium as gym
from gymnasium.envs.registration import register
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.evaluation import evaluate_policy

# --- 1. CARICAMENTO MODELLO ---
print("Caricamento modello da ./logs/udr_experiment_2x/udr_baseline_2x.zip ...")
model = SAC.load("./logs/udr_experiment_2x/udr_baseline_2x", device="cpu")

# print("Caricamento modello da ./logs/udr_experiment_1.1x/udr_baseline_1.1x.zip ...")
# model = SAC.load("./logs/udr_experiment_1.1x/udr_baseline_1.1x", device="cpu")

# print("Caricamento modello da ./logs/udr_experiment_10x/udr_baseline_10x.zip ...")
# model = SAC.load("./logs/udr_experiment_10x/udr_baseline_10x", device="cpu")

# --- 3. CONFIGURAZIONE ---
mass_shifts = [-2, -1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5, 2.0]
n_eval_episodes = 20
results_mean = []
results_std = []

print(f"\nAvvio valutazione robustezza su {len(mass_shifts)} configurazioni...")
print("-" * 60)

# --- 4. LOOP DI VALUTAZIONE ---
for shift in mass_shifts:
    env = gym.make("CustomHopper-shift-v0", mass_shift=shift)
    env = DummyVecEnv([lambda: env])
    
    norm_path = f"./logs/udr_experiment_2x/udr_baseline_2x_vecnormalize.pkl"
    # norm_path = f"./logs/udr_experiment_1.1x/udr_baseline_1.1x_vecnormalize.pkl"
    # norm_path = f"./logs/udr_experiment_10x/udr_baseline_10x_vecnormalize.pkl"
    try:
        env = VecNormalize.load(norm_path, env)
        env.training = False      
        env.norm_reward = False   
    except FileNotFoundError:
        pass 

    episode_rewards, episode_lengths = evaluate_policy(
        model, 
        env, 
        n_eval_episodes=n_eval_episodes, 
        deterministic=True, 
        return_episode_rewards=True
    )
    
    mean_r = np.mean(episode_rewards)
    std_r = np.std(episode_rewards)
    results_mean.append(mean_r)
    results_std.append(std_r)
    
    print(f"Shift {shift:+.1f} kg | Reward: {mean_r:8.2f} +/- {std_r:6.2f}")
    
    env.close()

# --- 5. PLOTTING (BARRE + CURVA) ---
results_mean = np.array(results_mean)
results_std = np.array(results_std)

if 0.0 in mass_shifts:
    baseline_idx = mass_shifts.index(0.0)
    baseline_reward = results_mean[baseline_idx]
else:
    baseline_reward = np.max(results_mean)

percentages = (results_mean / baseline_reward) * 100

# Creazione Grafici
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

bar_width = 0.4
x_pos = np.arange(len(mass_shifts))

# --- Grafico A: Performance Assoluta ---
# 1. Le Barre
bars1 = ax1.bar(x_pos, results_mean, yerr=results_std, align='center', 
               alpha=0.6, ecolor='black', capsize=5, width=bar_width, 
               color='royalblue', label='Average Reward (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax1.plot(x_pos, results_mean, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax1.axhline(y=baseline_reward, color='red', linestyle='--', linewidth=1.5, label='Baseline')
ax1.set_title('Absolute Performance vs. Torso Mass Shift')
ax1.set_xlabel('Torso Mass Shift (kg)')
ax1.set_ylabel('Mean Reward')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(mass_shifts)
ax1.grid(True, axis='y', alpha=0.3)
ax1.legend()

# Etichette barre
ax1.bar_label(bars1, fmt='%.0f', padding=3)


# --- Grafico B: Performance Relativa ---
# 1. Le Barre
bars2 = ax2.bar(x_pos, percentages, align='center', 
                alpha=0.6, width=bar_width, 
                color='purple', label='% of Baseline (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax2.plot(x_pos, percentages, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax2.axhline(y=100.0, color='black', linestyle='--', alpha=0.5, label='Baseline (100%)')
ax2.set_title('Robustness Profile (% of Baseline)')
ax2.set_xlabel('Torso Mass Shift (kg)')
ax2.set_ylabel('Performance (%)')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(mass_shifts)
ax2.set_ylim(0, max(115, np.max(percentages) + 10)) 
ax2.grid(True, axis='y', alpha=0.3)
ax2.legend()

# Etichette barre
ax2.bar_label(bars2, fmt='%.1f%%', padding=3)

plt.tight_layout()
plt.show()
# Out:
# Caricamento modello da ./logs/udr_experiment_2x/udr_baseline_2x.zip ...
#
# Avvio valutazione robustezza su 9 configurazioni...
# ------------------------------------------------------------
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Shift -2.0 kg | Reward:  1376.61 +/-   9.41
# Shift -1.5 kg | Reward:  1506.97 +/-   3.75
# Shift -1.0 kg | Reward:  1582.02 +/-   2.81
# Shift -0.5 kg | Reward:  1604.66 +/-  11.34
# Shift +0.0 kg | Reward:  1655.24 +/-  10.39
# Shift +0.5 kg | Reward:  1697.34 +/-  36.15
# Shift +1.0 kg | Reward:  1434.61 +/- 115.02
# Shift +1.5 kg | Reward:  1112.40 +/-  34.27
# Shift +2.0 kg | Reward:  1197.56 +/-  54.91

# %%
import matplotlib.pyplot as plt
import numpy as np
import gymnasium as gym
from gymnasium.envs.registration import register
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.evaluation import evaluate_policy

# --- 1. CARICAMENTO MODELLO ---
# print("Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...")
# model = SAC.load("./logs/udr_experiment/udr_baseline", device="cpu")

print("Caricamento modello da ./logs/udr_experiment_1.1x/udr_baseline_1.1x.zip ...")
model = SAC.load("./logs/udr_experiment_1.1x/udr_baseline_1.1x", device="cpu")

# print("Caricamento modello da ./logs/udr_experiment_10x/udr_baseline_10x.zip ...")
# model = SAC.load("./logs/udr_experiment_10x/udr_baseline_10x", device="cpu")

# --- 3. CONFIGURAZIONE ---
floor_friction_shifts = [-0.9, -0.6, -0.3, 0.0, 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7]
n_eval_episodes = 20
results_mean = []
results_std = []

print(f"\nAvvio valutazione robustezza su {len(floor_friction_shifts)} configurazioni...")
print("-" * 60)

# --- 4. LOOP DI VALUTAZIONE ---
for shift in floor_friction_shifts:
    env = gym.make("CustomHopper-shift-v0", floor_friction_shift=shift, mass_shift=0.0)
    env = DummyVecEnv([lambda: env])
    
    # norm_path = f"./logs/udr_experiment/udr_baseline_vecnormalize.pkl"
    norm_path = f"./logs/udr_experiment_1.1x/udr_baseline_1.1x_vecnormalize.pkl"
    # norm_path = f"./logs/udr_experiment_10x/udr_baseline_10x_vecnormalize.pkl"
    try:
        env = VecNormalize.load(norm_path, env)
        env.training = False      
        env.norm_reward = False   
    except FileNotFoundError:
        pass 

    episode_rewards, episode_lengths = evaluate_policy(
        model, 
        env, 
        n_eval_episodes=n_eval_episodes, 
        deterministic=True, 
        return_episode_rewards=True
    )
    
    mean_r = np.mean(episode_rewards)
    std_r = np.std(episode_rewards)
    results_mean.append(mean_r)
    results_std.append(std_r)
    
    print(f"Shift {shift:+.2f} | Reward: {mean_r:8.2f} +/- {std_r:6.2f}")
    
    env.close()

# --- 5. PLOTTING (BARRE + CURVA) ---
results_mean = np.array(results_mean)
results_std = np.array(results_std)

if 0.0 in floor_friction_shifts:
    baseline_idx = floor_friction_shifts.index(0.0)
    baseline_reward = results_mean[baseline_idx]
else:
    baseline_reward = np.max(results_mean)

percentages = (results_mean / baseline_reward) * 100

# Creazione Grafici
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

bar_width = 0.4
x_pos = np.arange(len(floor_friction_shifts))

# --- Grafico A: Performance Assoluta ---
# 1. Le Barre
bars1 = ax1.bar(x_pos, results_mean, yerr=results_std, align='center', 
               alpha=0.6, ecolor='black', capsize=5, width=bar_width, 
               color='royalblue', label='Average Reward (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax1.plot(x_pos, results_mean, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax1.axhline(y=baseline_reward, color='red', linestyle='--', linewidth=1.5, label='Baseline')
ax1.set_title('Absolute Performance vs. Floor Friction Shift')
ax1.set_xlabel('Floor Friction Shift')
ax1.set_ylabel('Mean Reward')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(floor_friction_shifts)
ax1.grid(True, axis='y', alpha=0.3)
ax1.legend()

# Etichette barre
ax1.bar_label(bars1, fmt='%.0f', padding=3)


# --- Grafico B: Performance Relativa ---
# 1. Le Barre
bars2 = ax2.bar(x_pos, percentages, align='center', 
                alpha=0.6, width=bar_width, 
                color='purple', label='% of Baseline (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax2.plot(x_pos, percentages, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax2.axhline(y=100.0, color='black', linestyle='--', alpha=0.5, label='Baseline (100%)')
ax2.set_title('Robustness Profile (% of Baseline)')
ax2.set_xlabel('Floor Friction Shift')
ax2.set_ylabel('Performance (%)')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(floor_friction_shifts)
ax2.set_ylim(0, max(115, np.max(percentages) + 10)) 
ax2.grid(True, axis='y', alpha=0.3)
ax2.legend()

# Etichette barre
ax2.bar_label(bars2, fmt='%.1f%%', padding=3)

plt.tight_layout()
plt.show()
# Out:
# Caricamento modello da ./logs/udr_experiment_1.1x/udr_baseline_1.1x.zip ...
#
# Avvio valutazione robustezza su 13 configurazioni...
# ------------------------------------------------------------
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Shift -0.90 | Reward:  1859.97 +/-  44.67
# Shift -0.60 | Reward:  1838.06 +/-  49.21
# Shift -0.30 | Reward:  1847.65 +/-  48.06
# Shift +0.00 | Reward:  1849.99 +/-  47.18
# Shift +0.30 | Reward:  1861.36 +/-  46.45
# Shift +0.60 | Reward:  1867.89 +/-  57.64
# Shift +0.90 | Reward:  1865.37 +/-  53.82
# Shift +1.20 | Reward:  1574.27 +/-  38.59
# Shift +1.50 | Reward:  1536.82 +/-  77.53
# Shift +1.80 | Reward:   547.73 +/-   9.50
# Shift +2.10 | Reward:   446.68 +/-   3.70
# Shift +2.40 | Reward:   378.83 +/-   2.06
# Shift +2.70 | Reward:   308.59 +/-   1.90

# %%
# RENDERING THE TRAINED AGENT

import gymnasium as gym
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import time

# --- CONFIGURATION ---
# Use the same 'model_name' from your previous cell, or type it manually here
# e.g., model_name = "SAC_doraemon_0"
env_to_render = 'CustomHopper-source-v0' # Change to 'target' to see the Real/Shifted env

# 1. Setup the Environment with Rendering Enabled
# render_mode="human" creates the popup window
env = DummyVecEnv([lambda: gym.make(env_to_render, render_mode="human")])

# 2. Load the Normalization Statistics (CRITICAL)
# If you skip this, the agent will see "wrong" numbers and fail immediately
norm_path = f"./logs/{model_name}_vecnormalize.pkl"
try:
    env = VecNormalize.load(norm_path, env)
    # We must disable training and reward normalization for inference
    env.training = False
    env.norm_reward = False
    print(f"Loaded Normalization stats from {norm_path}")
except FileNotFoundError:
    print("Warning: No normalization stats found. Running with RAW observations.")

# 3. Load the Trained Model
model_path = f"./logs/{model_name}_model.zip"
model = SAC.load(model_path)

# 4. The Simulation Loop
print(f"Starting rendering for {env_to_render}...")
obs = env.reset()

try:
    # Run for 1000 steps (or until you stop it)
    for _ in range(1000):
        # Get the action from the agent
        action, _ = model.predict(obs, deterministic=True)
        
        # Step the environment
        obs, rewards, dones, info = env.step(action)
        
        # Render the frame
        env.render()
        
        # Slow down slightly so you can see what's happening (Macs run this very fast)
        time.sleep(0.02)
        
        if dones[0]:
            print("Agent fell over! Resetting...")
            obs = env.reset()
            # time.sleep(1.0) # Pause briefly on failure if you want to see the crash

except KeyboardInterrupt:
    print("Simulation stopped by user.")
finally:
    env.close()

# %%
env = gym.make("CustomHopper-shift-v0", mass_shift=shift)
env.unwrapped.model.geom_friction

# %%
from env.custom_hopper import CustomHopper
import gymnasium as gym

env = CustomHopper(domain="source")

print("Body Masses:")
for i in range(env.unwrapped.model.body_mass.shape[0]):
    print(f"Body {env.unwrapped.model.body(i).name} mass: {env.unwrapped.model.body_mass[i]}")

print ("\nFriction coefficients:")
for i in range(env.unwrapped.model.geom_friction.shape[0]):
    print(f"Body {env.unwrapped.model.geom(i).name} friction: {env.unwrapped.model.geom_friction[i]}")

print ("\nDamping coefficients:")
for i in range(env.unwrapped.model.dof_damping.shape[0]):
    print(f"Body {env.unwrapped.model.joint(i).name} damping: {env.unwrapped.model.dof_damping[i]}")
