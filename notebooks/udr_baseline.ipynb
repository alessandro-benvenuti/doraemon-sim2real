# %%
import sys
import os
sys.path.append(os.path.abspath('../')) # Point to project root

# %%
import importlib
import modules.beta_trainer
import modules.utils
import modules.callbacks
import modules.env
import env.custom_hopper

# Force reload of the modules you changed
importlib.reload(modules.env)
importlib.reload(modules.callbacks)
importlib.reload(modules.utils)
importlib.reload(modules.beta_trainer)
importlib.reload(env.custom_hopper)

# Re-import the specific functions into the global namespace
from modules.beta_trainer import train_agent
from modules.utils import *
from env.custom_hopper import *

print("Modules reloaded successfully!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[33], line 2
#       1 import importlib
# ----> 2 import modules.beta_trainer
#       3 import modules.utils
#       4 import modules.callbacks
#
# File ~/Desktop/Università/Robot_Learning/project/project-extension-bartolini_benvenuti/modules/beta_trainer.py:18
#      16 # Import your NEW wrapper and callback
#      17 from modules.env import GaussianHopperWrapper, BetaHopperWrapper, UDRHopperWrapper
# ---> 18 from modules.callbacks import BetaDoraemonCallback
#      21 def make_wrapped_env(env_id, mode='source'):
#      22     """Factory for the environment."""
#
# ImportError: cannot import name 'BetaDoraemonCallback' from 'modules.callbacks' (/Users/alessandrobenvenuti/Desktop/Università/Robot_Learning/project/project-extension-bartolini_benvenuti/modules/callbacks.py)

# %%
from modules.beta_trainer import train_agent
from modules.utils import *
from env.custom_hopper import *

# %%
config = {
    'env_id': 'CustomHopper-source-v0',
    'algo': 'sac',
    'seed': 42,
    'timesteps': 1_000_000,
    'n_envs': 4,
    'vectorize': True,
    'normalize': True, 
    'lr': 1e-3,
    'gradient_steps': 2,
    'train_freq': 1,
    
    'mode': "udr"

}

# %%
# Training
train_agent(config, model_name="udr_baseline_10x", log_dir="./logs/udr_experiment_10x/")
# Out:
# Training with mode: udr
# --- STARTING NEW TRAINING ---
# Using cpu device
# Skipping DoraemonCallback for mode: udr
# Logging to ./tensorboard_logs/SAC_28
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 15.2     |
# |    ep_rew_mean     | 6.92     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 1516     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 120      |
# | train/             |          |
# |    actor_loss      | -3.9     |
# |    critic_loss     | 1.37     |
# |    ent_coef        | 0.994    |
# |    ent_coef_loss   | -0.0328  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8        |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.9     |
# |    ep_rew_mean     | 10.9     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 684      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 180      |
# | train/             |          |
# |    actor_loss      | -4.73    |
# |    critic_loss     | 0.476    |
# |    ent_coef        | 0.964    |
# |    ent_coef_loss   | -0.184   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 38       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | 12.4     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 445      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 344      |
# | train/             |          |
# |    actor_loss      | -5.17    |
# |    critic_loss     | 0.36     |
# |    ent_coef        | 0.888    |
# |    ent_coef_loss   | -0.597   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 120      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.9     |
# |    ep_rew_mean     | 16.4     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 412      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 452      |
# | train/             |          |
# |    actor_loss      | -5.49    |
# |    critic_loss     | 0.31     |
# |    ent_coef        | 0.842    |
# |    ent_coef_loss   | -0.865   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.6     |
# |    ep_rew_mean     | 16.5     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 378      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 576      |
# | train/             |          |
# |    actor_loss      | -5.75    |
# |    critic_loss     | 0.183    |
# |    ent_coef        | 0.791    |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 236      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | 19.8     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 360      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 704      |
# | train/             |          |
# |    actor_loss      | -6.09    |
# |    critic_loss     | 0.253    |
# |    ent_coef        | 0.742    |
# |    ent_coef_loss   | -1.48    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 300      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 28.6     |
# |    ep_rew_mean     | 22.1     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 349      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 896      |
# | train/             |          |
# |    actor_loss      | -6.44    |
# |    critic_loss     | 0.268    |
# |    ent_coef        | 0.675    |
# |    ent_coef_loss   | -1.92    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 396      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 30.5     |
# |    ep_rew_mean     | 24.1     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 343      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1052     |
# | train/             |          |
# |    actor_loss      | -6.96    |
# |    critic_loss     | 0.155    |
# |    ent_coef        | 0.625    |
# |    ent_coef_loss   | -2.31    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 474      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 32.2     |
# |    ep_rew_mean     | 27.1     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 337      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 1196     |
# | train/             |          |
# |    actor_loss      | -7.47    |
# |    critic_loss     | 0.211    |
# |    ent_coef        | 0.583    |
# |    ent_coef_loss   | -2.61    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 546      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 35.6     |
# |    ep_rew_mean     | 32       |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 332      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 1476     |
# | train/             |          |
# |    actor_loss      | -8.01    |
# |    critic_loss     | 0.536    |
# |    ent_coef        | 0.509    |
# |    ent_coef_loss   | -3.16    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 686      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 37.7     |
# |    ep_rew_mean     | 35.9     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 329      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 1864     |
# | train/             |          |
# |    actor_loss      | -9.64    |
# |    critic_loss     | 0.477    |
# |    ent_coef        | 0.423    |
# |    ent_coef_loss   | -3.92    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 880      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 42.2     |
# |    ep_rew_mean     | 42.1     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 327      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2184     |
# | train/             |          |
# |    actor_loss      | -10.5    |
# |    critic_loss     | 0.272    |
# |    ent_coef        | 0.365    |
# |    ent_coef_loss   | -4.36    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1040     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.1     |
# |    ep_rew_mean     | 45.2     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 327      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2356     |
# | train/             |          |
# |    actor_loss      | -10.9    |
# |    critic_loss     | 0.459    |
# |    ent_coef        | 0.337    |
# |    ent_coef_loss   | -4.48    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1126     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 44.5     |
# |    ep_rew_mean     | 44.9     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 325      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 2540     |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.3      |
# |    ent_coef        | 0.31     |
# |    ent_coef_loss   | -4.99    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1218     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.6     |
# |    ep_rew_mean     | 46.8     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 324      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 2816     |
# | train/             |          |
# |    actor_loss      | -12.4    |
# |    critic_loss     | 0.401    |
# |    ent_coef        | 0.274    |
# |    ent_coef_loss   | -5.46    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1356     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.5     |
# |    ep_rew_mean     | 47.1     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 321      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 2984     |
# | train/             |          |
# |    actor_loss      | -13.2    |
# |    critic_loss     | 0.399    |
# |    ent_coef        | 0.254    |
# |    ent_coef_loss   | -5.47    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1440     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.7     |
# |    ep_rew_mean     | 48.1     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 321      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 3184     |
# | train/             |          |
# |    actor_loss      | -13.6    |
# |    critic_loss     | 0.377    |
# |    ent_coef        | 0.232    |
# |    ent_coef_loss   | -5.82    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1540     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 45.8     |
# |    ep_rew_mean     | 48.5     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 320      |
# |    time_elapsed    | 10       |
# |    total_timesteps | 3464     |
# | train/             |          |
# |    actor_loss      | -14.1    |
# |    critic_loss     | 0.484    |
# |    ent_coef        | 0.205    |
# |    ent_coef_loss   | -6.01    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1680     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.8     |
# |    ep_rew_mean     | 50.7     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 318      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 3636     |
# | train/             |          |
# |    actor_loss      | -14.8    |
# |    critic_loss     | 0.303    |
# |    ent_coef        | 0.189    |
# |    ent_coef_loss   | -6.38    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1766     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 46.7     |
# |    ep_rew_mean     | 50.9     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 317      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 3812     |
# | train/             |          |
# |    actor_loss      | -14.6    |
# |    critic_loss     | 0.462    |
# |    ent_coef        | 0.175    |
# |    ent_coef_loss   | -6.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1854     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.2     |
# |    ep_rew_mean     | 52       |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 316      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 4012     |
# | train/             |          |
# |    actor_loss      | -15.4    |
# |    critic_loss     | 0.387    |
# |    ent_coef        | 0.16     |
# |    ent_coef_loss   | -7.16    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1954     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.2     |
# |    ep_rew_mean     | 52.3     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 315      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 4264     |
# | train/             |          |
# |    actor_loss      | -16.1    |
# |    critic_loss     | 0.322    |
# |    ent_coef        | 0.143    |
# |    ent_coef_loss   | -6.99    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2080     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 47.7     |
# |    ep_rew_mean     | 53.5     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 315      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 4440     |
# | train/             |          |
# |    actor_loss      | -16.9    |
# |    critic_loss     | 0.512    |
# |    ent_coef        | 0.132    |
# |    ent_coef_loss   | -7.33    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2168     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.2     |
# |    ep_rew_mean     | 54.6     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 316      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 4724     |
# | train/             |          |
# |    actor_loss      | -17.4    |
# |    critic_loss     | 0.442    |
# |    ent_coef        | 0.117    |
# |    ent_coef_loss   | -7.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2310     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 48.2     |
# |    ep_rew_mean     | 55.3     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 317      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 4876     |
# | train/             |          |
# |    actor_loss      | -17.5    |
# |    critic_loss     | 0.508    |
# |    ent_coef        | 0.11     |
# |    ent_coef_loss   | -7.55    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2386     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 49.3     |
# |    ep_rew_mean     | 57.1     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 317      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 5056     |
# | train/             |          |
# |    actor_loss      | -17.8    |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.102    |
# |    ent_coef_loss   | -7.75    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2476     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50.5     |
# |    ep_rew_mean     | 59.2     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 315      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 5296     |
# | train/             |          |
# |    actor_loss      | -18.4    |
# |    critic_loss     | 0.617    |
# |    ent_coef        | 0.092    |
# |    ent_coef_loss   | -7.04    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2596     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 51.6     |
# |    ep_rew_mean     | 61.3     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 316      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 5520     |
# | train/             |          |
# |    actor_loss      | -18.9    |
# |    critic_loss     | 0.425    |
# |    ent_coef        | 0.0841   |
# |    ent_coef_loss   | -7       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2708     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 52.5     |
# |    ep_rew_mean     | 63.2     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 317      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 5692     |
# | train/             |          |
# |    actor_loss      | -19.3    |
# |    critic_loss     | 1.04     |
# |    ent_coef        | 0.0787   |
# |    ent_coef_loss   | -7.42    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2794     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 53.8     |
# |    ep_rew_mean     | 66.5     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 318      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 5896     |
# | train/             |          |
# |    actor_loss      | -20.3    |
# |    critic_loss     | 1.13     |
# |    ent_coef        | 0.073    |
# |    ent_coef_loss   | -7.26    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2896     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.6     |
# |    ep_rew_mean     | 68.5     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 319      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 6192     |
# | train/             |          |
# |    actor_loss      | -20.7    |
# |    critic_loss     | 0.542    |
# |    ent_coef        | 0.0655   |
# |    ent_coef_loss   | -7.48    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3044     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 54.9     |
# |    ep_rew_mean     | 68.8     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 319      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 6428     |
# | train/             |          |
# |    actor_loss      | -21      |
# |    critic_loss     | 0.729    |
# |    ent_coef        | 0.0604   |
# |    ent_coef_loss   | -6.24    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3162     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.3     |
# |    ep_rew_mean     | 72.9     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 318      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 6732     |
# | train/             |          |
# |    actor_loss      | -21.7    |
# |    critic_loss     | 1.08     |
# |    ent_coef        | 0.0546   |
# |    ent_coef_loss   | -5.34    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3314     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.8     |
# |    ep_rew_mean     | 74.1     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 317      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 6904     |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 0.656    |
# |    ent_coef        | 0.0519   |
# |    ent_coef_loss   | -5.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3400     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.9     |
# |    ep_rew_mean     | 72.8     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 314      |
# |    time_elapsed    | 22       |
# |    total_timesteps | 7184     |
# | train/             |          |
# |    actor_loss      | -22      |
# |    critic_loss     | 1.46     |
# |    ent_coef        | 0.048    |
# |    ent_coef_loss   | -3       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3540     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.4     |
# |    ep_rew_mean     | 74.7     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 314      |
# |    time_elapsed    | 23       |
# |    total_timesteps | 7492     |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.045    |
# |    ent_coef_loss   | -3.49    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3694     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.7     |
# |    ep_rew_mean     | 75.8     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 314      |
# |    time_elapsed    | 24       |
# |    total_timesteps | 7680     |
# | train/             |          |
# |    actor_loss      | -23.2    |
# |    critic_loss     | 1.67     |
# |    ent_coef        | 0.0436   |
# |    ent_coef_loss   | -4.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3788     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.4     |
# |    ep_rew_mean     | 78.3     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 315      |
# |    time_elapsed    | 25       |
# |    total_timesteps | 8016     |
# | train/             |          |
# |    actor_loss      | -23.6    |
# |    critic_loss     | 0.916    |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | -1.15    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3956     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.2     |
# |    ep_rew_mean     | 78.5     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 314      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 8192     |
# | train/             |          |
# |    actor_loss      | -24.7    |
# |    critic_loss     | 1.13     |
# |    ent_coef        | 0.0404   |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4044     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.5     |
# |    ep_rew_mean     | 77.3     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 315      |
# |    time_elapsed    | 26       |
# |    total_timesteps | 8372     |
# | train/             |          |
# |    actor_loss      | -25.6    |
# |    critic_loss     | 1.25     |
# |    ent_coef        | 0.0396   |
# |    ent_coef_loss   | -1.74    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4134     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.5     |
# |    ep_rew_mean     | 77.2     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 315      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 8548     |
# | train/             |          |
# |    actor_loss      | -25.4    |
# |    critic_loss     | 1.09     |
# |    ent_coef        | 0.0388   |
# |    ent_coef_loss   | -1.92    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4222     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.3     |
# |    ep_rew_mean     | 78.6     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 315      |
# |    time_elapsed    | 27       |
# |    total_timesteps | 8772     |
# | train/             |          |
# |    actor_loss      | -25.6    |
# |    critic_loss     | 1.62     |
# |    ent_coef        | 0.0378   |
# |    ent_coef_loss   | -0.453   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4334     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.1     |
# |    ep_rew_mean     | 78.2     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 316      |
# |    time_elapsed    | 28       |
# |    total_timesteps | 8948     |
# | train/             |          |
# |    actor_loss      | -26.2    |
# |    critic_loss     | 1.03     |
# |    ent_coef        | 0.0371   |
# |    ent_coef_loss   | -2.04    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4422     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 55.7     |
# |    ep_rew_mean     | 77.7     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 316      |
# |    time_elapsed    | 29       |
# |    total_timesteps | 9284     |
# | train/             |          |
# |    actor_loss      | -28.5    |
# |    critic_loss     | 1.02     |
# |    ent_coef        | 0.0355   |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4590     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.1     |
# |    ep_rew_mean     | 81.2     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 315      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 9476     |
# | train/             |          |
# |    actor_loss      | -27.5    |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.035    |
# |    ent_coef_loss   | -0.568   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4686     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.6     |
# |    ep_rew_mean     | 80.1     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 315      |
# |    time_elapsed    | 30       |
# |    total_timesteps | 9644     |
# | train/             |          |
# |    actor_loss      | -27.9    |
# |    critic_loss     | 2.95     |
# |    ent_coef        | 0.0346   |
# |    ent_coef_loss   | -1.23    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4770     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 56.5     |
# |    ep_rew_mean     | 79.6     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 314      |
# |    time_elapsed    | 31       |
# |    total_timesteps | 9972     |
# | train/             |          |
# |    actor_loss      | -29.9    |
# |    critic_loss     | 1.15     |
# |    ent_coef        | 0.0336   |
# |    ent_coef_loss   | 0.159    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4934     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.1     |
# |    ep_rew_mean     | 81.4     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 314      |
# |    time_elapsed    | 32       |
# |    total_timesteps | 10220    |
# | train/             |          |
# |    actor_loss      | -29.9    |
# |    critic_loss     | 1.53     |
# |    ent_coef        | 0.0329   |
# |    ent_coef_loss   | -0.046   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5058     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.5     |
# |    ep_rew_mean     | 83.5     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 313      |
# |    time_elapsed    | 33       |
# |    total_timesteps | 10520    |
# | train/             |          |
# |    actor_loss      | -30.9    |
# |    critic_loss     | 1.29     |
# |    ent_coef        | 0.0322   |
# |    ent_coef_loss   | -1.26    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5208     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 57.8     |
# |    ep_rew_mean     | 83.8     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 313      |
# |    time_elapsed    | 34       |
# |    total_timesteps | 10688    |
# | train/             |          |
# |    actor_loss      | -30.8    |
# |    critic_loss     | 1.83     |
# |    ent_coef        | 0.0317   |
# |    ent_coef_loss   | 1.09     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5292     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 58.4     |
# |    ep_rew_mean     | 85       |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 313      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 10996    |
# | train/             |          |
# |    actor_loss      | -31.6    |
# |    critic_loss     | 1.85     |
# |    ent_coef        | 0.031    |
# |    ent_coef_loss   | -1.31    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5446     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59       |
# |    ep_rew_mean     | 87       |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 314      |
# |    time_elapsed    | 35       |
# |    total_timesteps | 11168    |
# | train/             |          |
# |    actor_loss      | -31.3    |
# |    critic_loss     | 1.39     |
# |    ent_coef        | 0.0308   |
# |    ent_coef_loss   | -1.77    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5532     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 58.7     |
# |    ep_rew_mean     | 86.1     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 314      |
# |    time_elapsed    | 36       |
# |    total_timesteps | 11340    |
# | train/             |          |
# |    actor_loss      | -33.5    |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.0308   |
# |    ent_coef_loss   | 0.717    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5618     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.6     |
# |    ep_rew_mean     | 89.5     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 314      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 11748    |
# | train/             |          |
# |    actor_loss      | -34.4    |
# |    critic_loss     | 2.08     |
# |    ent_coef        | 0.031    |
# |    ent_coef_loss   | -0.231   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5822     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 59.4     |
# |    ep_rew_mean     | 88.4     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 314      |
# |    time_elapsed    | 38       |
# |    total_timesteps | 12092    |
# | train/             |          |
# |    actor_loss      | -34.1    |
# |    critic_loss     | 2.11     |
# |    ent_coef        | 0.0318   |
# |    ent_coef_loss   | 1.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5994     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60       |
# |    ep_rew_mean     | 89.8     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 315      |
# |    time_elapsed    | 39       |
# |    total_timesteps | 12572    |
# | train/             |          |
# |    actor_loss      | -36.2    |
# |    critic_loss     | 1.99     |
# |    ent_coef        | 0.0336   |
# |    ent_coef_loss   | -0.562   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6234     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 61.2     |
# |    ep_rew_mean     | 93.4     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 315      |
# |    time_elapsed    | 40       |
# |    total_timesteps | 12820    |
# | train/             |          |
# |    actor_loss      | -35.2    |
# |    critic_loss     | 1.73     |
# |    ent_coef        | 0.0347   |
# |    ent_coef_loss   | 0.225    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6358     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 60.8     |
# |    ep_rew_mean     | 92.4     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 315      |
# |    time_elapsed    | 41       |
# |    total_timesteps | 13220    |
# | train/             |          |
# |    actor_loss      | -37.7    |
# |    critic_loss     | 2.01     |
# |    ent_coef        | 0.0368   |
# |    ent_coef_loss   | -1.06    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6558     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.7     |
# |    ep_rew_mean     | 95.9     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 316      |
# |    time_elapsed    | 42       |
# |    total_timesteps | 13444    |
# | train/             |          |
# |    actor_loss      | -38.4    |
# |    critic_loss     | 3.9      |
# |    ent_coef        | 0.037    |
# |    ent_coef_loss   | 0.226    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6670     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.9     |
# |    ep_rew_mean     | 99.9     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 316      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 13656    |
# | train/             |          |
# |    actor_loss      | -38.9    |
# |    critic_loss     | 3.54     |
# |    ent_coef        | 0.038    |
# |    ent_coef_loss   | 0.0848   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6776     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.8     |
# |    ep_rew_mean     | 96.9     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 316      |
# |    time_elapsed    | 43       |
# |    total_timesteps | 13864    |
# | train/             |          |
# |    actor_loss      | -39.5    |
# |    critic_loss     | 3.16     |
# |    ent_coef        | 0.0381   |
# |    ent_coef_loss   | 0.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6880     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.1     |
# |    ep_rew_mean     | 94.5     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 316      |
# |    time_elapsed    | 44       |
# |    total_timesteps | 14184    |
# | train/             |          |
# |    actor_loss      | -40.8    |
# |    critic_loss     | 3.68     |
# |    ent_coef        | 0.0386   |
# |    ent_coef_loss   | 1.47     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7040     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.1     |
# |    ep_rew_mean     | 94.8     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 317      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 14432    |
# | train/             |          |
# |    actor_loss      | -41.5    |
# |    critic_loss     | 3.63     |
# |    ent_coef        | 0.0395   |
# |    ent_coef_loss   | 0.393    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7164     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.1     |
# |    ep_rew_mean     | 94.8     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 317      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 14688    |
# | train/             |          |
# |    actor_loss      | -39.5    |
# |    critic_loss     | 4.16     |
# |    ent_coef        | 0.0395   |
# |    ent_coef_loss   | -0.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7292     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65       |
# |    ep_rew_mean     | 97.5     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 317      |
# |    time_elapsed    | 46       |
# |    total_timesteps | 14856    |
# | train/             |          |
# |    actor_loss      | -41.6    |
# |    critic_loss     | 4.46     |
# |    ent_coef        | 0.0397   |
# |    ent_coef_loss   | 0.998    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7376     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.9     |
# |    ep_rew_mean     | 97.3     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 317      |
# |    time_elapsed    | 47       |
# |    total_timesteps | 15116    |
# | train/             |          |
# |    actor_loss      | -42.2    |
# |    critic_loss     | 2.63     |
# |    ent_coef        | 0.0421   |
# |    ent_coef_loss   | -0.477   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7506     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.1     |
# |    ep_rew_mean     | 98.2     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 317      |
# |    time_elapsed    | 48       |
# |    total_timesteps | 15296    |
# | train/             |          |
# |    actor_loss      | -40.8    |
# |    critic_loss     | 3.69     |
# |    ent_coef        | 0.0433   |
# |    ent_coef_loss   | 1.03     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7596     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.4     |
# |    ep_rew_mean     | 99.5     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 318      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 15640    |
# | train/             |          |
# |    actor_loss      | -43.1    |
# |    critic_loss     | 5.55     |
# |    ent_coef        | 0.045    |
# |    ent_coef_loss   | 0.0294   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7768     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.6     |
# |    ep_rew_mean     | 99.5     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 318      |
# |    time_elapsed    | 49       |
# |    total_timesteps | 15828    |
# | train/             |          |
# |    actor_loss      | -45.1    |
# |    critic_loss     | 3.04     |
# |    ent_coef        | 0.0447   |
# |    ent_coef_loss   | -0.266   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7862     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.9     |
# |    ep_rew_mean     | 97.1     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 318      |
# |    time_elapsed    | 50       |
# |    total_timesteps | 16016    |
# | train/             |          |
# |    actor_loss      | -43.7    |
# |    critic_loss     | 5.68     |
# |    ent_coef        | 0.045    |
# |    ent_coef_loss   | 0.059    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7956     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.7     |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 318      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 16340    |
# | train/             |          |
# |    actor_loss      | -44.7    |
# |    critic_loss     | 4.16     |
# |    ent_coef        | 0.0465   |
# |    ent_coef_loss   | 1.63     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8118     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.5     |
# |    ep_rew_mean     | 102      |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 318      |
# |    time_elapsed    | 51       |
# |    total_timesteps | 16532    |
# | train/             |          |
# |    actor_loss      | -45.6    |
# |    critic_loss     | 2.98     |
# |    ent_coef        | 0.0478   |
# |    ent_coef_loss   | 1.32     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8214     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.4     |
# |    ep_rew_mean     | 98.3     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 319      |
# |    time_elapsed    | 52       |
# |    total_timesteps | 16780    |
# | train/             |          |
# |    actor_loss      | -45.9    |
# |    critic_loss     | 4.56     |
# |    ent_coef        | 0.0486   |
# |    ent_coef_loss   | 0.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8338     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65       |
# |    ep_rew_mean     | 96.3     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 319      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 16972    |
# | train/             |          |
# |    actor_loss      | -44.5    |
# |    critic_loss     | 5.13     |
# |    ent_coef        | 0.0497   |
# |    ent_coef_loss   | 0.674    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8434     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.8     |
# |    ep_rew_mean     | 96.1     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 319      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 17168    |
# | train/             |          |
# |    actor_loss      | -45.6    |
# |    critic_loss     | 4.9      |
# |    ent_coef        | 0.0498   |
# |    ent_coef_loss   | -0.00488 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8532     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.2     |
# |    ep_rew_mean     | 97.2     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 319      |
# |    time_elapsed    | 54       |
# |    total_timesteps | 17568    |
# | train/             |          |
# |    actor_loss      | -48.3    |
# |    critic_loss     | 4.75     |
# |    ent_coef        | 0.0526   |
# |    ent_coef_loss   | 0.435    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8732     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.8     |
# |    ep_rew_mean     | 97.5     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 319      |
# |    time_elapsed    | 55       |
# |    total_timesteps | 17752    |
# | train/             |          |
# |    actor_loss      | -47.7    |
# |    critic_loss     | 4.77     |
# |    ent_coef        | 0.0537   |
# |    ent_coef_loss   | -0.685   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8824     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.7     |
# |    ep_rew_mean     | 97.3     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 319      |
# |    time_elapsed    | 56       |
# |    total_timesteps | 17920    |
# | train/             |          |
# |    actor_loss      | -47.4    |
# |    critic_loss     | 8.19     |
# |    ent_coef        | 0.0545   |
# |    ent_coef_loss   | -0.0849  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8908     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 64.8     |
# |    ep_rew_mean     | 94.3     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 320      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 18312    |
# | train/             |          |
# |    actor_loss      | -50.4    |
# |    critic_loss     | 5.67     |
# |    ent_coef        | 0.0548   |
# |    ent_coef_loss   | 1.04     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9104     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.8     |
# |    ep_rew_mean     | 96.4     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 320      |
# |    time_elapsed    | 57       |
# |    total_timesteps | 18480    |
# | train/             |          |
# |    actor_loss      | -48.9    |
# |    critic_loss     | 4.02     |
# |    ent_coef        | 0.0562   |
# |    ent_coef_loss   | 0.249    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9188     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 65.2     |
# |    ep_rew_mean     | 94.8     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 320      |
# |    time_elapsed    | 59       |
# |    total_timesteps | 18924    |
# | train/             |          |
# |    actor_loss      | -49.5    |
# |    critic_loss     | 5.78     |
# |    ent_coef        | 0.0561   |
# |    ent_coef_loss   | 0.129    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9410     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 67.4     |
# |    ep_rew_mean     | 96.5     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 320      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 19260    |
# | train/             |          |
# |    actor_loss      | -52.1    |
# |    critic_loss     | 4.74     |
# |    ent_coef        | 0.0557   |
# |    ent_coef_loss   | 0.583    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9578     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 66.4     |
# |    ep_rew_mean     | 93.7     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 320      |
# |    time_elapsed    | 60       |
# |    total_timesteps | 19436    |
# | train/             |          |
# |    actor_loss      | -53.6    |
# |    critic_loss     | 6.88     |
# |    ent_coef        | 0.0573   |
# ...
# |    actor_loss      | -73.2    |
# |    critic_loss     | 27.6     |
# |    ent_coef        | 0.0147   |
# |    ent_coef_loss   | 0.292    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 494654   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.5     |
# |    ep_rew_mean     | 123      |
# | time/              |          |
# |    episodes        | 10080    |
# |    fps             | 339      |
# |    time_elapsed    | 2913     |
# |    total_timesteps | 989920   |
# | train/             |          |
# |    actor_loss      | -72.2    |
# |    critic_loss     | 23.8     |
# |    ent_coef        | 0.0177   |
# |    ent_coef_loss   | 0.164    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 494908   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.8     |
# |    ep_rew_mean     | 124      |
# | time/              |          |
# |    episodes        | 10084    |
# |    fps             | 339      |
# |    time_elapsed    | 2914     |
# |    total_timesteps | 990248   |
# | train/             |          |
# |    actor_loss      | -73.9    |
# |    critic_loss     | 9.66     |
# |    ent_coef        | 0.018    |
# |    ent_coef_loss   | -1.31    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495072   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85       |
# |    ep_rew_mean     | 116      |
# | time/              |          |
# |    episodes        | 10088    |
# |    fps             | 339      |
# |    time_elapsed    | 2915     |
# |    total_timesteps | 990604   |
# | train/             |          |
# |    actor_loss      | -76.3    |
# |    critic_loss     | 11.3     |
# |    ent_coef        | 0.0166   |
# |    ent_coef_loss   | -0.841   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495250   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.2     |
# |    ep_rew_mean     | 118      |
# | time/              |          |
# |    episodes        | 10092    |
# |    fps             | 339      |
# |    time_elapsed    | 2916     |
# |    total_timesteps | 990944   |
# | train/             |          |
# |    actor_loss      | -70.6    |
# |    critic_loss     | 9.56     |
# |    ent_coef        | 0.0169   |
# |    ent_coef_loss   | -0.716   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495420   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 82.5     |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    episodes        | 10096    |
# |    fps             | 339      |
# |    time_elapsed    | 2917     |
# |    total_timesteps | 991328   |
# | train/             |          |
# |    actor_loss      | -73.8    |
# |    critic_loss     | 26.8     |
# |    ent_coef        | 0.0175   |
# |    ent_coef_loss   | 2.53     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495612   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.5     |
# |    ep_rew_mean     | 120      |
# | time/              |          |
# |    episodes        | 10100    |
# |    fps             | 339      |
# |    time_elapsed    | 2918     |
# |    total_timesteps | 991620   |
# | train/             |          |
# |    actor_loss      | -74.7    |
# |    critic_loss     | 11.9     |
# |    ent_coef        | 0.0173   |
# |    ent_coef_loss   | 0.349    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495758   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.2     |
# |    ep_rew_mean     | 121      |
# | time/              |          |
# |    episodes        | 10104    |
# |    fps             | 339      |
# |    time_elapsed    | 2918     |
# |    total_timesteps | 991792   |
# | train/             |          |
# |    actor_loss      | -74.3    |
# |    critic_loss     | 7.16     |
# |    ent_coef        | 0.0174   |
# |    ent_coef_loss   | 0.186    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 495844   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.9     |
# |    ep_rew_mean     | 123      |
# | time/              |          |
# |    episodes        | 10108    |
# |    fps             | 339      |
# |    time_elapsed    | 2919     |
# |    total_timesteps | 992192   |
# | train/             |          |
# |    actor_loss      | -73.8    |
# |    critic_loss     | 7.67     |
# |    ent_coef        | 0.0185   |
# |    ent_coef_loss   | -0.0838  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 496044   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.4     |
# |    ep_rew_mean     | 125      |
# | time/              |          |
# |    episodes        | 10112    |
# |    fps             | 339      |
# |    time_elapsed    | 2921     |
# |    total_timesteps | 992836   |
# | train/             |          |
# |    actor_loss      | -74.4    |
# |    critic_loss     | 6.04     |
# |    ent_coef        | 0.0197   |
# |    ent_coef_loss   | 0.479    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 496366   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.1     |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 10116    |
# |    fps             | 339      |
# |    time_elapsed    | 2923     |
# |    total_timesteps | 993536   |
# | train/             |          |
# |    actor_loss      | -72.4    |
# |    critic_loss     | 15.8     |
# |    ent_coef        | 0.0178   |
# |    ent_coef_loss   | 0.636    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 496716   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 95.8     |
# |    ep_rew_mean     | 135      |
# | time/              |          |
# |    episodes        | 10120    |
# |    fps             | 339      |
# |    time_elapsed    | 2925     |
# |    total_timesteps | 994204   |
# | train/             |          |
# |    actor_loss      | -72.8    |
# |    critic_loss     | 21.6     |
# |    ent_coef        | 0.0171   |
# |    ent_coef_loss   | -0.509   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 497050   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.4     |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 10124    |
# |    fps             | 339      |
# |    time_elapsed    | 2927     |
# |    total_timesteps | 994712   |
# | train/             |          |
# |    actor_loss      | -73.8    |
# |    critic_loss     | 15.3     |
# |    ent_coef        | 0.0169   |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 497304   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 96.6     |
# |    ep_rew_mean     | 137      |
# | time/              |          |
# |    episodes        | 10128    |
# |    fps             | 339      |
# |    time_elapsed    | 2928     |
# |    total_timesteps | 995220   |
# | train/             |          |
# |    actor_loss      | -76.1    |
# |    critic_loss     | 20.5     |
# |    ent_coef        | 0.016    |
# |    ent_coef_loss   | 1.82     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 497558   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 97.1     |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 10132    |
# |    fps             | 339      |
# |    time_elapsed    | 2929     |
# |    total_timesteps | 995400   |
# | train/             |          |
# |    actor_loss      | -71.6    |
# |    critic_loss     | 10.1     |
# |    ent_coef        | 0.0162   |
# |    ent_coef_loss   | -1.67    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 497648   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.5     |
# |    ep_rew_mean     | 135      |
# | time/              |          |
# |    episodes        | 10136    |
# |    fps             | 339      |
# |    time_elapsed    | 2930     |
# |    total_timesteps | 995752   |
# | train/             |          |
# |    actor_loss      | -73.8    |
# |    critic_loss     | 24.3     |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | 1.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 497824   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 91.7     |
# |    ep_rew_mean     | 134      |
# | time/              |          |
# |    episodes        | 10140    |
# |    fps             | 339      |
# |    time_elapsed    | 2930     |
# |    total_timesteps | 995920   |
# | train/             |          |
# |    actor_loss      | -74.9    |
# |    critic_loss     | 9.79     |
# |    ent_coef        | 0.0191   |
# |    ent_coef_loss   | -0.072   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 497908   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 90.4     |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 10144    |
# |    fps             | 339      |
# |    time_elapsed    | 2931     |
# |    total_timesteps | 996152   |
# | train/             |          |
# |    actor_loss      | -74.5    |
# |    critic_loss     | 23.2     |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | -0.139   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498024   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.7     |
# |    ep_rew_mean     | 125      |
# | time/              |          |
# |    episodes        | 10148    |
# |    fps             | 339      |
# |    time_elapsed    | 2932     |
# |    total_timesteps | 996376   |
# | train/             |          |
# |    actor_loss      | -72.1    |
# |    critic_loss     | 22.3     |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | 2.94     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498136   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 86.3     |
# |    ep_rew_mean     | 127      |
# | time/              |          |
# |    episodes        | 10152    |
# |    fps             | 339      |
# |    time_elapsed    | 2932     |
# |    total_timesteps | 996592   |
# | train/             |          |
# |    actor_loss      | -76.1    |
# |    critic_loss     | 9.38     |
# |    ent_coef        | 0.0221   |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498244   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.9     |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 10156    |
# |    fps             | 339      |
# |    time_elapsed    | 2934     |
# |    total_timesteps | 997236   |
# | train/             |          |
# |    actor_loss      | -72.4    |
# |    critic_loss     | 5.94     |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | -1.92    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498566   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.4     |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 10160    |
# |    fps             | 339      |
# |    time_elapsed    | 2935     |
# |    total_timesteps | 997504   |
# | train/             |          |
# |    actor_loss      | -74.9    |
# |    critic_loss     | 19.7     |
# |    ent_coef        | 0.0214   |
# |    ent_coef_loss   | 1.73     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498700   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.4     |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    episodes        | 10164    |
# |    fps             | 339      |
# |    time_elapsed    | 2936     |
# |    total_timesteps | 997764   |
# | train/             |          |
# |    actor_loss      | -75      |
# |    critic_loss     | 6.07     |
# |    ent_coef        | 0.0204   |
# |    ent_coef_loss   | -0.333   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498830   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89       |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    episodes        | 10168    |
# |    fps             | 339      |
# |    time_elapsed    | 2936     |
# |    total_timesteps | 998016   |
# | train/             |          |
# |    actor_loss      | -73.6    |
# |    critic_loss     | 21.3     |
# |    ent_coef        | 0.02     |
# |    ent_coef_loss   | 1.5      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 498956   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88       |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    episodes        | 10172    |
# |    fps             | 339      |
# |    time_elapsed    | 2937     |
# |    total_timesteps | 998284   |
# | train/             |          |
# |    actor_loss      | -71.4    |
# |    critic_loss     | 9.3      |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | 0.931    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499090   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 88.4     |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 10176    |
# |    fps             | 339      |
# |    time_elapsed    | 2938     |
# |    total_timesteps | 998704   |
# | train/             |          |
# |    actor_loss      | -71.4    |
# |    critic_loss     | 13.1     |
# |    ent_coef        | 0.0188   |
# |    ent_coef_loss   | 0.591    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499300   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.3     |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 10180    |
# |    fps             | 339      |
# |    time_elapsed    | 2940     |
# |    total_timesteps | 999252   |
# | train/             |          |
# |    actor_loss      | -76.4    |
# |    critic_loss     | 10.8     |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | -0.797   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499574   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 94.8     |
# |    ep_rew_mean     | 139      |
# | time/              |          |
# |    episodes        | 10184    |
# |    fps             | 339      |
# |    time_elapsed    | 2942     |
# |    total_timesteps | 999952   |
# | train/             |          |
# |    actor_loss      | -73.6    |
# |    critic_loss     | 9.08     |
# |    ent_coef        | 0.0156   |
# |    ent_coef_loss   | -0.132   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 499924   |
# ---------------------------------
# (<stable_baselines3.sac.sac.SAC at 0x29d95a7c0>,
#  <stable_baselines3.common.vec_env.vec_normalize.VecNormalize at 0x29d995ca0>,
#  None)

# %%
# ONLY USE IF TRAINING WAS INTERRUPTED AND YOU HAVE CHECKPOINTS

import os
import re

# CHECKPOINT VERIFICATION

checkpoint_dir = "./logs/checkpoints"
if os.path.exists(checkpoint_dir):
    print("Files found:", os.listdir(checkpoint_dir))
else:
    print("No checkpoints found! The interrupt save didn't work.")


# RESUME TRAINING FROM CHECKPOINT

# 1. Find the latest checkpoint step
log_dir = "./logs/"
ckpt_dir = os.path.join(log_dir, "checkpoints")

latest_step = None
if os.path.exists(ckpt_dir):
    # regex to find numbers in filenames
    steps = [int(re.search(r'\d+', f).group()) for f in os.listdir(ckpt_dir) if "model_" in f]
    if steps:
        latest_step = max(steps)

print(f"Resuming from step: {latest_step}")

# 2. Resume Training
if latest_step is not None:
    # Pass the step number to resume_step
    model, env, doraemon_cb = train_agent(config, log_dir=log_dir, resume_step=latest_step)
else:
    print("Could not find a checkpoint to resume.")

# %%
# Used to visualize training metrics through TensorBoard
! tensorboard --logdir ./tensorboard_logs/

# Note: if you want to run Tensorboard from terminal, simply use the command above
# Out:
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/tensorboard/default.py:30: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# TensorFlow installation not found - running with reduced feature set.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.20.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
import json
import numpy as np

class DoraemonMockCallback:
    def __init__(self, json_path):
        # Load the JSON data
        with open(json_path, 'r') as f:
            data = json.load(f)
        
        # Extract the history
        self.history = data.get("history", {}) 
        
        print(f"Data loaded. Updates found: {len(self.history.get('entropy', []))}")


doraemon_cb = DoraemonMockCallback('logs/doraemon_state_20000000.json')

plot_doraemon_dynamics(doraemon_cb)
# Out:
# Data loaded. Updates found: 541

# %%
from modules.utils import *
from stable_baselines3 import SAC

# Define the raw environments
source_env = gym.make('CustomHopper-source-v0')
target_env = gym.make('CustomHopper-target-v0')

# Reconstruct the model name used in training
model_name = f"{config['algo']}_doraemon_{config['seed']}"
model_name = "final"

print("Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...")
model = SAC.load("./logs/udr_experiment/udr_baseline", device="cpu")

# Run evaluation
evaluate_sim2real(model, source_env, target_env, log_dir="./logs/", model_name=model_name)
# Out:
# Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...
# Loaded Normalization stats from ./logs//final_vecnormalize.pkl
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# --- Evaluating on SOURCE Env (Simulation) ---
# Reward: 43.91 +/- 0.93
# Length: 25.70 +/- 0.56 steps
#
# --- Evaluating on TARGET Env (Real/Shifted) ---
# Reward: 46.95 +/- 1.24
# Length: 28.70 +/- 0.78 steps
# (np.float64(43.90747263431549), np.float64(46.9465738594532))

# %%
import matplotlib.pyplot as plt
import numpy as np
import gymnasium as gym
from gymnasium.envs.registration import register
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.evaluation import evaluate_policy

# --- 1. CARICAMENTO MODELLO ---
print("Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...")
# model = SAC.load("./logs/udr_experiment/udr_baseline", device="cpu")

print("Caricamento modello da ./logs/udr_experiment_10x/udr_baseline_10x.zip ...")
model = SAC.load("./logs/udr_experiment_10x/udr_baseline_10x", device="cpu")

# --- 3. CONFIGURAZIONE ---
mass_shifts = [-2, -1.5, -1.0, -0.5, 0.0, 0.5, 1.0, 1.5, 2.0]
n_eval_episodes = 20
results_mean = []
results_std = []

print(f"\nAvvio valutazione robustezza su {len(mass_shifts)} configurazioni...")
print("-" * 60)

# --- 4. LOOP DI VALUTAZIONE ---
for shift in mass_shifts:
    env = gym.make("CustomHopper-shift-v0", mass_shift=shift)
    env = DummyVecEnv([lambda: env])
    
    norm_path = f"./logs/udr_experiment/udr_baseline_vecnormalize.pkl"
    norm_path = f"./logs/udr_experiment_10x/udr_baseline_10x_vecnormalize.pkl"
    try:
        env = VecNormalize.load(norm_path, env)
        env.training = False      
        env.norm_reward = False   
    except FileNotFoundError:
        pass 

    episode_rewards, episode_lengths = evaluate_policy(
        model, 
        env, 
        n_eval_episodes=n_eval_episodes, 
        deterministic=True, 
        return_episode_rewards=True
    )
    
    mean_r = np.mean(episode_rewards)
    std_r = np.std(episode_rewards)
    results_mean.append(mean_r)
    results_std.append(std_r)
    
    print(f"Shift {shift:+.1f} kg | Reward: {mean_r:8.2f} +/- {std_r:6.2f}")
    
    env.close()

# --- 5. PLOTTING (BARRE + CURVA) ---
results_mean = np.array(results_mean)
results_std = np.array(results_std)

if 0.0 in mass_shifts:
    baseline_idx = mass_shifts.index(0.0)
    baseline_reward = results_mean[baseline_idx]
else:
    baseline_reward = np.max(results_mean)

percentages = (results_mean / baseline_reward) * 100

# Creazione Grafici
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

bar_width = 0.4
x_pos = np.arange(len(mass_shifts))

# --- Grafico A: Performance Assoluta ---
# 1. Le Barre
bars1 = ax1.bar(x_pos, results_mean, yerr=results_std, align='center', 
               alpha=0.6, ecolor='black', capsize=5, width=bar_width, 
               color='royalblue', label='Average Reward (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax1.plot(x_pos, results_mean, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax1.axhline(y=baseline_reward, color='red', linestyle='--', linewidth=1.5, label='Baseline')
ax1.set_title('Absolute Performance vs. Torso Mass Shift')
ax1.set_xlabel('Torso Mass Shift (kg)')
ax1.set_ylabel('Mean Reward')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(mass_shifts)
ax1.grid(True, axis='y', alpha=0.3)
ax1.legend()

# Etichette barre
ax1.bar_label(bars1, fmt='%.0f', padding=3)


# --- Grafico B: Performance Relativa ---
# 1. Le Barre
bars2 = ax2.bar(x_pos, percentages, align='center', 
                alpha=0.6, width=bar_width, 
                color='purple', label='% of Baseline (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax2.plot(x_pos, percentages, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax2.axhline(y=100.0, color='black', linestyle='--', alpha=0.5, label='Baseline (100%)')
ax2.set_title('Robustness Profile (% of Baseline)')
ax2.set_xlabel('Torso Mass Shift (kg)')
ax2.set_ylabel('Performance (%)')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(mass_shifts)
ax2.set_ylim(0, max(115, np.max(percentages) + 10)) 
ax2.grid(True, axis='y', alpha=0.3)
ax2.legend()

# Etichette barre
ax2.bar_label(bars2, fmt='%.1f%%', padding=3)

plt.tight_layout()
plt.show()
# Out:
# Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...
# Caricamento modello da ./logs/udr_experiment_10x/udr_baseline_10x.zip ...
#
# Avvio valutazione robustezza su 9 configurazioni...
# ------------------------------------------------------------
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Shift -2.0 kg | Reward:   454.80 +/-   6.65
# Shift -1.5 kg | Reward:   484.62 +/-   8.29
# Shift -1.0 kg | Reward:   475.84 +/-   6.22
# Shift -0.5 kg | Reward:   458.84 +/-  15.16
# Shift +0.0 kg | Reward:   405.84 +/-   6.51
# Shift +0.5 kg | Reward:   379.56 +/-   3.31
# Shift +1.0 kg | Reward:   366.50 +/-   1.97
# Shift +1.5 kg | Reward:   361.29 +/-   3.75
# Shift +2.0 kg | Reward:   362.32 +/-   2.52

# %%
import matplotlib.pyplot as plt
import numpy as np
import gymnasium as gym
from gymnasium.envs.registration import register
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.evaluation import evaluate_policy

# --- 1. CARICAMENTO MODELLO ---
print("Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...")
model = SAC.load("./logs/udr_experiment/udr_baseline", device="cpu")

# --- 3. CONFIGURAZIONE ---
floor_friction_shifts = [-0.9, -0.6, -0.3, 0.0, 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7]
n_eval_episodes = 20
results_mean = []
results_std = []

print(f"\nAvvio valutazione robustezza su {len(floor_friction_shifts)} configurazioni...")
print("-" * 60)

# --- 4. LOOP DI VALUTAZIONE ---
for shift in floor_friction_shifts:
    env = gym.make("CustomHopper-shift-v0", floor_friction_shift=shift, mass_shift=0.0)
    env = DummyVecEnv([lambda: env])
    
    norm_path = f"./logs/udr_experiment/udr_baseline_vecnormalize.pkl"
    try:
        env = VecNormalize.load(norm_path, env)
        env.training = False      
        env.norm_reward = False   
    except FileNotFoundError:
        pass 

    episode_rewards, episode_lengths = evaluate_policy(
        model, 
        env, 
        n_eval_episodes=n_eval_episodes, 
        deterministic=True, 
        return_episode_rewards=True
    )
    
    mean_r = np.mean(episode_rewards)
    std_r = np.std(episode_rewards)
    results_mean.append(mean_r)
    results_std.append(std_r)
    
    print(f"Shift {shift:+.2f} | Reward: {mean_r:8.2f} +/- {std_r:6.2f}")
    
    env.close()

# --- 5. PLOTTING (BARRE + CURVA) ---
results_mean = np.array(results_mean)
results_std = np.array(results_std)

if 0.0 in floor_friction_shifts:
    baseline_idx = floor_friction_shifts.index(0.0)
    baseline_reward = results_mean[baseline_idx]
else:
    baseline_reward = np.max(results_mean)

percentages = (results_mean / baseline_reward) * 100

# Creazione Grafici
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

bar_width = 0.4
x_pos = np.arange(len(floor_friction_shifts))

# --- Grafico A: Performance Assoluta ---
# 1. Le Barre
bars1 = ax1.bar(x_pos, results_mean, yerr=results_std, align='center', 
               alpha=0.6, ecolor='black', capsize=5, width=bar_width, 
               color='royalblue', label='Average Reward (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax1.plot(x_pos, results_mean, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax1.axhline(y=baseline_reward, color='red', linestyle='--', linewidth=1.5, label='Baseline')
ax1.set_title('Absolute Performance vs. Floor Friction Shift')
ax1.set_xlabel('Floor Friction Shift')
ax1.set_ylabel('Mean Reward')
ax1.set_xticks(x_pos)
ax1.set_xticklabels(floor_friction_shifts)
ax1.grid(True, axis='y', alpha=0.3)
ax1.legend()

# Etichette barre
ax1.bar_label(bars1, fmt='%.0f', padding=3)


# --- Grafico B: Performance Relativa ---
# 1. Le Barre
bars2 = ax2.bar(x_pos, percentages, align='center', 
                alpha=0.6, width=bar_width, 
                color='purple', label='% of Baseline (Bar)')

# 2. La Curva in sovraimpressione (Trend)
ax2.plot(x_pos, percentages, color='darkorange', marker='o', linewidth=2.5, label='Trend (Line)')

ax2.axhline(y=100.0, color='black', linestyle='--', alpha=0.5, label='Baseline (100%)')
ax2.set_title('Robustness Profile (% of Baseline)')
ax2.set_xlabel('Floor Friction Shift')
ax2.set_ylabel('Performance (%)')
ax2.set_xticks(x_pos)
ax2.set_xticklabels(floor_friction_shifts)
ax2.set_ylim(0, max(115, np.max(percentages) + 10)) 
ax2.grid(True, axis='y', alpha=0.3)
ax2.legend()

# Etichette barre
ax2.bar_label(bars2, fmt='%.1f%%', padding=3)

plt.tight_layout()
plt.show()
# Out:
# Caricamento modello da ./logs/udr_experiment/udr_baseline.zip ...
#
# Avvio valutazione robustezza su 13 configurazioni...
# ------------------------------------------------------------
# /Users/alessandrobenvenuti/miniconda3/envs/RL_lab04/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Shift -0.90 | Reward:  1681.50 +/-  50.43
# Shift -0.60 | Reward:  1678.74 +/-  50.36
# Shift -0.30 | Reward:  1688.20 +/-  45.50
# Shift +0.00 | Reward:  1668.06 +/-  44.85
# Shift +0.30 | Reward:  1685.77 +/-  54.43
# Shift +0.60 | Reward:  1683.75 +/-  49.34
# Shift +0.90 | Reward:  1672.16 +/-  45.55
# Shift +1.20 | Reward:  1313.14 +/- 151.48
# Shift +1.50 | Reward:  1427.73 +/- 185.30
# Shift +1.80 | Reward:   890.68 +/-  20.07
# Shift +2.10 | Reward:   477.17 +/-   8.69
# Shift +2.40 | Reward:   391.61 +/-   1.63
# Shift +2.70 | Reward:   341.31 +/-   1.49

# %%
# RENDERING THE TRAINED AGENT

import gymnasium as gym
from stable_baselines3 import SAC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import time

# --- CONFIGURATION ---
# Use the same 'model_name' from your previous cell, or type it manually here
# e.g., model_name = "SAC_doraemon_0"
env_to_render = 'CustomHopper-source-v0' # Change to 'target' to see the Real/Shifted env

# 1. Setup the Environment with Rendering Enabled
# render_mode="human" creates the popup window
env = DummyVecEnv([lambda: gym.make(env_to_render, render_mode="human")])

# 2. Load the Normalization Statistics (CRITICAL)
# If you skip this, the agent will see "wrong" numbers and fail immediately
norm_path = f"./logs/{model_name}_vecnormalize.pkl"
try:
    env = VecNormalize.load(norm_path, env)
    # We must disable training and reward normalization for inference
    env.training = False
    env.norm_reward = False
    print(f"Loaded Normalization stats from {norm_path}")
except FileNotFoundError:
    print("Warning: No normalization stats found. Running with RAW observations.")

# 3. Load the Trained Model
model_path = f"./logs/{model_name}_model.zip"
model = SAC.load(model_path)

# 4. The Simulation Loop
print(f"Starting rendering for {env_to_render}...")
obs = env.reset()

try:
    # Run for 1000 steps (or until you stop it)
    for _ in range(1000):
        # Get the action from the agent
        action, _ = model.predict(obs, deterministic=True)
        
        # Step the environment
        obs, rewards, dones, info = env.step(action)
        
        # Render the frame
        env.render()
        
        # Slow down slightly so you can see what's happening (Macs run this very fast)
        time.sleep(0.02)
        
        if dones[0]:
            print("Agent fell over! Resetting...")
            obs = env.reset()
            # time.sleep(1.0) # Pause briefly on failure if you want to see the crash

except KeyboardInterrupt:
    print("Simulation stopped by user.")
finally:
    env.close()

# %%
env = gym.make("CustomHopper-shift-v0", mass_shift=shift)
env.unwrapped.model.geom_friction

# %%
from env.custom_hopper import CustomHopper
import gymnasium as gym

env = CustomHopper(domain="source")

print("Body Masses:")
for i in range(env.unwrapped.model.body_mass.shape[0]):
    print(f"Body {env.unwrapped.model.body(i).name} mass: {env.unwrapped.model.body_mass[i]}")

print ("\nFriction coefficients:")
for i in range(env.unwrapped.model.geom_friction.shape[0]):
    print(f"Body {env.unwrapped.model.geom(i).name} friction: {env.unwrapped.model.geom_friction[i]}")

print ("\nDamping coefficients:")
for i in range(env.unwrapped.model.dof_damping.shape[0]):
    print(f"Body {env.unwrapped.model.joint(i).name} damping: {env.unwrapped.model.dof_damping[i]}")
